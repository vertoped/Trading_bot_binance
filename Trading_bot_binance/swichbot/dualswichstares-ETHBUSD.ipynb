# %%
import requests
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import copy
import time
import random
import threading
import coinconfig

from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
from binance.helpers import round_step_size
from futures_sign import send_signed_request, send_public_request
from cred import KEY, SECRET

# %%
#0:BTCBUSD, 1:BTCUSDT, 2:DOGEUSDT, 3:DOGEBUSD, 4:ETHBUSD, 5:ETHUSDT, 6:EOSUSDT, 7:LTCUSDT, 8:BNBBUSD

# %%
client = Client(KEY, SECRET, testnet=False)
config=coinconfig.tradeconfig
coin=coinconfig.coinlist[4]

# %%
symbol=coin["symbol"]
asset=coin["asset"]
recvWindow=config["recvWindow"]
dualSidePosition=config["dualSidePosition"]
marginType=config["marginType"]

leverage=coin["leverage"]
roundity=coin["roundity"]
profit_percent=coin["profit_percent"]
diference=coin["diference"]
stop_percent=profit_percent-diference
balance_part=coin["balance_part"]
compensation=coin["compensation"]
ingebit=coin["ingebit"]

# %%
client.futures_change_leverage(symbol=symbol, leverage=leverage, recvWindow=recvWindow)
# Out:
# {'symbol': 'ETHBUSD', 'leverage': 50, 'maxNotionalValue': '50000'}

# %%
# Margin type
def margin_type_to_isolated():
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    body=positions[positions['symbol']==symbol]['isolated'].astype(bool).tolist()[0]

    if body==True:
        client.futures_change_margin_type(symbol=symbol, marginType=marginType, recvWindow=recvWindow)
        print(f'Changed to {marginType}')
    else:
        print(f'Already {marginType}')

# %%
margin_type_to_isolated()
# Out:
# Already CROSSED

# %%
# Hedge mode turn on

def hedge_mode_turn_on():
    status=client.futures_get_position_mode() 
    if status['dualSidePosition']==False:
        client.futures_change_position_mode(dualSidePosition=dualSidePosition, recvWindow=recvWindow)
        client.futures_get_position_mode()
        print('Dual turned on')
    else:
        print('Already Dual')
    return(status['dualSidePosition'])

# %%
hedge_mode_turn_on()
# Out:
# Already Dual
# True

# %%
def get_assetbalance(symbol):
    status = client.futures_account()
    balance = pd.DataFrame(status['assets'])
    assetbalance = float(balance.loc[balance['asset'] == asset, 'availableBalance'])
    return(assetbalance)

# %%
# Find all opened positions

def get_opened_positions(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    open_positions=positions[positions['symbol']==symbol]
    position_long=float(open_positions[open_positions['positionSide']=='LONG']['entryPrice'])
    position_short=float(open_positions[open_positions['positionSide']=='SHORT']['entryPrice'])
    return(position_long,position_short)

# %%
get_opened_positions(symbol)
# Out:
# (1215.55, 1215.54)

# %%
def get_quant(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    open_positions=positions[positions['symbol']==symbol]
    quant=float(open_positions[open_positions['positionSide']=='LONG']['positionAmt'])
    if quant==0:
        quant=abs(float(open_positions[open_positions['positionSide']=='SHORT']['positionAmt']))
    return(quant)

# %%
# Close all orders 

def check_and_close_orders(symbol):
    global isStop 
    a=client.futures_get_open_orders(symbol=symbol)
    if len(a)>0:
        isStop = False
        client.futures_cancel_all_open_orders(symbol=symbol)

# %%
def get_symbol_price(symbol):
    prices = client.get_all_tickers()
    df=pd.DataFrame(prices)
    return float(df[ df['symbol']==symbol]['price'])

# %%
get_symbol_price(symbol)
# Out:
# 1215.5

# %%
#получить tick size

def get_tick_size(symbol):
    data = client.futures_exchange_info()
    tick_size = 0.0
    the_symbol = symbol

    found = False
    info = data['symbols']
    for s in range(len(info)):
        if info[s]['symbol'] == the_symbol:
            filters = info[s]['filters']
            for f in range(len(filters)):
                if filters[f]['filterType'] == 'PRICE_FILTER':
                    tick_size = float(filters[f]['tickSize'])
                    found = True
                    break
            break
    return(tick_size)

# %%
#Trade config

# maxposition=0.016 #1 = 100% = 1 BTC,
asset_balance=get_assetbalance(symbol)
symbol_price=get_symbol_price(symbol)
maxposition=round(asset_balance*balance_part*leverage/symbol_price,3)
quantity=str(round(maxposition/2,roundity))
tick_size=get_tick_size(symbol)
symbolround=abs(str(tick_size).find('.') - len(str(tick_size))) - 1
quantity
# Out:
# '0.011'

# %%
#Stop loss LONG 
def open_sl_long(symbol,quant,tick_size,stop_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[0]
        stop_price_trigger=str(round(float(entry_price)*(1-stop_percent), symbolround))
        stop_price=str(round(float(stop_price_trigger)*0.9999, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "positionSide": "LONG",
                    "type": "STOP",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": stop_price_trigger,
                    "price": stop_price
                }
            ]
        }

        open_position_sl_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        long_sl_opened=float(open_position_sl_long_response[0]['price'])
        print('LONG sl order opened price:'+str(long_sl_opened))
        return(long_sl_opened)
    
    except :
        print('\n\nSL long not open...')

# %%
def open_sl_long_steps(symbol,quantity,tick_size,stop_percent):
    stop_step=stop_percent/5  
    quant=str(get_quant(symbol))
    # x = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*3/2))
    # x.start()
    y = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit),roundity)),tick_size,stop_step*2))
    y.start()
    z = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*5/2))
    z.start()
    w = threading.Thread(target=open_sl_long, args=(symbol,quant,tick_size,stop_step*3))
    w.start()

# %%
#Take Profit LONG 

def open_tp_long(symbol,quant,tick_size,profit_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[0]
        take_price_trigger=str(round(float(entry_price)*(1+profit_percent), symbolround))
        take_price=str(round(float(take_price_trigger)*0.9999, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "positionSide": "LONG",
                    "type": "TAKE_PROFIT",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": take_price_trigger,
                    "price": take_price
                }
            ]
        }
        open_position_tp_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        long_tp_opened=float(open_position_tp_long_response[0]['price'])
        print('LONG tp order opened price:'+str(long_tp_opened))
        return(long_tp_opened)
        
    except :
        print('\n\nTP long not open...')

# %%
def open_tp_long_steps(symbol,quantity,tick_size,profit_percent):
    quant=str(round(float(quantity)/(ingebit*1.5),roundity))
    profit_step=profit_percent/5
    
    # x = threading.Thread(target=open_tp_long, args=(symbol,quantity,tick_size,profit_percent))
    # x.start()
    # y = threading.Thread(target=open_tp_long, args=(symbol,quant,tick_size,profit_step))
    # y.start()
    z = threading.Thread(target=open_tp_long, args=(symbol,quant,tick_size,profit_step*2))
    z.start()
    w = threading.Thread(target=open_tp_long, args=(symbol,quantity,tick_size,profit_step*3))
    w.start()

# %%
#Открыть sl&tp LONG если есть позиция

def long_tp_sl_opening(symbol,quantity,profit_percent,stop_percent):
    position=get_opened_positions(symbol)
    if position[0]>0:
        x = threading.Thread(target=open_tp_long_steps, args=(symbol,quantity,tick_size,profit_percent))
        x.start()
        y = threading.Thread(target=open_sl_long_steps, args=(symbol,quantity,tick_size,stop_percent))
        y.start()

# %%
#Открыть позицию LONG 

def open_position_long(symbol,quantity,tick_size,profit_percent,stop_percent,close_price):
    tick=str(tick_size)
    params = {
        "batchOrders": [
            {
                "symbol":symbol,
                "side": "BUY",
                "positionSide": "LONG",
                "type": "LIMIT",
                "quantity": quantity,
                "timeInForce":"GTC",
                "tickSize": tick,
                "price": close_price        
            }
        ]
    }
    open_position_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
    long_opened=float(open_position_long_response[0]['price'])
    if long_opened>0:
        print('LONG order opened price:'+str(long_opened))
        long_tp_sl=long_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)
    else:
        print('LONG not open')

# %%
def open_position_long_steps(symbol,profit_percent):
    quant=str(round(float(quantity)/ingebit,roundity))
    sprice=get_symbol_price(symbol)
    close_price=str(round(sprice*(1+0.001),symbolround))
    open_position_long(symbol,quantity,tick_size,profit_percent,stop_percent,close_price)

# %%
#Stop loss SHORT 

def open_sl_short(symbol,quant,tick_size,stop_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[1]
        stop_price_trigger=str(round(float(entry_price)*(1+stop_percent), symbolround))
        stop_price=str(round(float(stop_price_trigger)*1.0001, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "positionSide": "SHORT",
                    "type": "STOP",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": stop_price_trigger,
                    "price": stop_price
                }
            ]
        }
        
        open_position_sl_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        short_sl_opened=float(open_position_sl_short_response[0]['price'])
        print('SHORT sl order opened price:'+str(short_sl_opened))
        return(short_sl_opened)
    
    except :
        print('\n\nSL short not open...')

# %%
def open_sl_short_steps(symbol,quantity,tick_size,stop_percent):
    stop_step=stop_percent/5  
    quant=str(get_quant(symbol))
    # x = threading.Thread(target=open_sl_short, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*3/2))
    # x.start()
    y = threading.Thread(target=open_sl_short, args=(symbol,str(round(float(quant)/(ingebit),roundity)),tick_size,stop_step*2))
    y.start()
    z = threading.Thread(target=open_sl_short, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*5/2))
    z.start()
    w = threading.Thread(target=open_sl_short, args=(symbol,quant,tick_size,stop_step*3))
    w.start()

# %%
#Take Profit SHORT

def open_tp_short(symbol,quant,tick_size,profit_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[1]
        take_price_trigger=str(round(float(entry_price)*(1-profit_percent), symbolround))
        take_price=str(round(float(take_price_trigger)*1.0001, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "positionSide": "SHORT",
                    "type": "TAKE_PROFIT",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": take_price_trigger,
                    "price": take_price
                }
            ]
        }

        open_position_tp_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        short_tp_opened=float(open_position_tp_short_response[0]['price'])
        print('SHORT tp order opened price:'+str(short_tp_opened))
        return(short_tp_opened)
    
    except :
        print('\n\nTp short not open...')

# %%
def open_tp_short_steps(symbol,quantity,tick_size,profit_percent):
    quant=str(round(float(quantity)/3,roundity))
    profit_step=profit_percent/5
    
    # x = threading.Thread(target=open_tp_short, args=(symbol,quantity,tick_size,profit_percent))
    # x.start()
    # y = threading.Thread(target=open_tp_short, args=(symbol,quant,tick_size,profit_step))
    # y.start()
    z = threading.Thread(target=open_tp_short, args=(symbol,quant,tick_size,profit_step*2))
    z.start()
    w = threading.Thread(target=open_tp_short, args=(symbol,quantity,tick_size,profit_step*3))
    w.start()

# %%
#Открыть sl&tp SHORT если есть позиция
       
def short_tp_sl_opening(symbol,quantity,profit_percent,stop_percent):
    position=get_opened_positions(symbol)
    if position[1]>0:
        x = threading.Thread(target=open_tp_short_steps, args=(symbol,quantity,tick_size,profit_percent))
        x.start()
        y = threading.Thread(target=open_sl_short_steps, args=(symbol,quantity,tick_size,stop_percent))
        y.start()

# %%
#Открыть позицию SHORT

def open_position_short(symbol,quantity,tick_size,profit_percent,stop_percent,close_price):
    tick=str(tick_size)
    params = {
        "batchOrders": [
            {
                "symbol":symbol,
                "side": "SELL",
                "positionSide": "SHORT",
                "type": "LIMIT",
                "quantity": quantity,
                "timeInForce":"GTC",
                "tickSize": tick,
                "price": close_price        
            }
        ]
    }
    open_position_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
    short_opened=float(open_position_short_response[0]['price'])    
    if short_opened>0:
        print('SHORT order opened price:'+str(short_opened))
        short_tp_sl=short_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)
    else:
        print('SHORT not open')

# %%
def open_position_short_steps(symbol,profit_percent):
    quant=str(round(float(quantity)/ingebit,roundity))
    sprice=get_symbol_price(symbol)
    close_price=str(round(sprice*(1-0.001),symbolround))
    open_position_short(symbol,quantity,tick_size,profit_percent,stop_percent,close_price)

# %%
def get_profit(symbol):
    trades = client.futures_account_trades(symbol=symbol)
    dataset=pd.DataFrame(trades).iloc[-10:]
    bnbcom=dataset[dataset['commissionAsset']=='BNB']['commission'].astype(float).sum()
    busdcom=dataset[dataset['commissionAsset']==asset]['commission'].astype(float).sum()
    com=(bnbcom*270+busdcom)*-1
    real=dataset['realizedPnl'].astype(float).sum()
    profit=float(com+real)
    dataseto=pd.DataFrame(trades)['realizedPnl'].astype(float)[-50:]
    dataseto=pd.DataFrame(dataseto)
    datasetneg=len(dataseto[dataseto['realizedPnl']<0].index)
    datasetpos=len(dataseto[dataseto['realizedPnl']>0].index)
    print(profit,'+',datasetpos,'-',datasetneg)

# %%
get_profit(symbol)
# Out:
# -0.11468074 + 11 - 23

# %%
def get_direction(symbol):
    trades = client.futures_account_trades(symbol=symbol)[-1:]
    dataset = pd.DataFrame(trades)
    resdata = float(dataset['realizedPnl'])
    direction=1
    if resdata < 0:
        direction=0
    return(direction)

# %%
get_direction(symbol)
# Out:
# 1

# %%
def changer(symbol):
    direction=get_direction(symbol)
    f = open("directdoc.txt", "r")
    direc=f.read()
    if direction==0: #реверс
        if direc=='0':
            x = threading.Thread(target=open_position_long_steps, args=(symbol,profit_percent*1.25))
            x.start()
            y = threading.Thread(target=open_position_short_steps, args=(symbol,profit_percent))
            y.start()
            print('Direction switched from SHORT to LONG')
            f = open("directdoc.txt", "w")
            f.write("1")
            f.close()
        else:
            x = threading.Thread(target=open_position_long_steps, args=(symbol,profit_percent))
            x.start()
            y = threading.Thread(target=open_position_short_steps, args=(symbol,profit_percent*1.25))
            y.start()
            print('Direction switched from LONG to SHORT')
            f = open("directdoc.txt", "w")
            f.write("0")
            f.close()
    else: 
        if direc=='0':
            x = threading.Thread(target=open_position_long_steps, args=(symbol,profit_percent))
            x.start()
            y = threading.Thread(target=open_position_short_steps, args=(symbol,profit_percent*1.25))
            y.start()
            print('Direction SHORT again')
            f = open("directdoc.txt", "w")
            f.write("0")
            f.close()
        if direc=='1':
            x = threading.Thread(target=open_position_long_steps, args=(symbol,profit_percent*1.25))
            x.start()
            y = threading.Thread(target=open_position_short_steps, args=(symbol,profit_percent))
            y.start()
            print('Direction LONG again')
            f = open("directdoc.txt", "w")
            f.write("1")
            f.close()

# %%
def check_positions_new(symbol):
    positions=get_opened_positions(symbol)
    orders=client.futures_get_open_orders(symbol=symbol)
    orders_df=pd.DataFrame(orders)
    if positions[0]+positions[1]==0:
        if orders_df.empty:
            changer(symbol)
            
    orders_tp_number=len(orders_df[orders_df['origType']=='TAKE_PROFIT'])
    if positions[0]>0 and (orders_tp_number==1 or orders_tp_number==3):
        sprice=get_symbol_price(symbol)
        if sprice<(positions[0])*(1+profit_percent/10):
            quant=str(round(get_quant(symbol),roundity))
            params={ 
                "batchOrders": [
                    {
                        "symbol":symbol, 
                        "positionSide": "LONG", 
                        "side":'SELL', 
                        "type":'MARKET',
                        "quantity":quant
                    }
                ]
            }
            one_stop=send_signed_request('POST', '/fapi/v1/batchOrders', params)
            if str(float(one_stop[0]['origQty']))==quant:
                print(f'Compensation LONG price {sprice}')

    if positions[1]>0 and (orders_tp_number==1 or orders_tp_number==3):
        sprice=get_symbol_price(symbol)
        if sprice>(positions[1])*(1-profit_percent/10):
            quant=str(round(get_quant(symbol),roundity))
            params={ 
                "batchOrders": [
                    {
                        "symbol":symbol, 
                        "positionSide": "SHORT", 
                        "side":'BUY', 
                        "type":'MARKET',
                        "quantity":quant
                    }
                ]
            }
            one_stop=send_signed_request('POST', '/fapi/v1/batchOrders', params)
            if str(float(one_stop[0]['origQty']))==quant:
                print(f'Compensation SHORT price {sprice}')
    else:
        print('Nothing to close')
#     else:

#         if positions[0]>0 and positions[1]==0:
#             quant=str(round(get_quant(symbol),roundity))
#             sprice=get_symbol_price(symbol)
#             asset=get_assetbalance(symbol)
#             if (asset*leverage)/(sprice*ingebit*2)>float(quant):
#                 if sprice<positions[0]*(1-profit_percent/4):
#                     sprice=get_symbol_price(symbol)
#                     close_price=str(round(sprice*(1-0.001),symbolround))                
#                     open_position_short(symbol,quant,tick_size,profit_percent,stop_percent,close_price)
#                     print('SHORT compensation opened')
#                     # client.futures_cancel_all_open_orders(symbol=symbol)
#                     # long_tp_sl_opening(symbol,quant,profit_percent,stop_percent)
#                 else:
#                     print('SHORT compensation not in condition')
#         if positions[1]>0 and positions[0]==0:
#             quant=str(round(get_quant(symbol),roundity))
#             sprice=get_symbol_price(symbol)
#             asset=get_assetbalance(symbol)
#             if (asset*leverage)/(sprice*ingebit*2)>float(quant):
#                 if sprice>positions[1]*(1+profit_percent/4):
#                     sprice=get_symbol_price(symbol)
#                     close_price=str(round(sprice*(1+0.001),symbolround))                
#                     open_position_long(symbol,quant,tick_size,profit_percent,stop_percent,close_price)
#                     print('LONG compensation opened')
#                     # client.futures_cancel_all_open_orders(symbol=symbol)
#                     # short_tp_sl_opening(symbol,quant,profit_percent,stop_percent)
#                 else:
#                     print('LONG compensation not in condition')

# %%
def check_step(symbol):
    quant=str(get_quant(symbol))
    sprice=get_symbol_price(symbol)
    asset=get_assetbalance(symbol)
    # if (asset*leverage)/(sprice*ingebit*2)>float(quant):
    positions=get_opened_positions(symbol)
    if positions[0]>0:
        if sprice>(positions[0])*(1+profit_percent/2):
            sprice=get_symbol_price(symbol)
            close_price=str(round(sprice*(1+0.001),symbolround))
            open_position_long(symbol,quant,tick_size,profit_percent,stop_percent,close_price)
            print('LONG addinational 1')
            # client.futures_cancel_all_open_orders(symbol=symbol)
            # short_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)

    if positions[1]>0:
        if sprice<(positions[1])*(1-profit_percent/2):
            sprice=get_symbol_price(symbol)
            close_price=str(round(sprice*(1-0.001),symbolround))
            open_position_short(symbol,quant,tick_size,profit_percent,stop_percent,close_price)
            print('SHORT addinational 1')
            # client.futures_cancel_all_open_orders(symbol=symbol)
            # long_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)
    else:
        print('No steps')

# %%
def order_clean(symbol):
    orders=client.futures_get_open_orders(symbol=symbol)
    orders_df=pd.DataFrame(orders)
    orders_sl=orders_df[orders_df['origType']=='STOP']
    orders_sl_short=orders_sl[orders_sl['positionSide']=='SHORT']
    orders_sl_long=orders_sl[orders_sl['positionSide']=='LONG']
    if len(orders_sl_short) > 3:
        ids = orders_df[orders_df['origType']=='STOP']['orderId'][-3:]
        client.futures_cancel_orders(
            symbol=symbol, origClientOrderIdList=ids
        )
    if len(orders_sl_long) > 3:
        ids = orders_df[orders_df['origType']=='STOP']['orderId'][-3:]
        client.futures_cancel_orders(
            symbol=symbol, origClientOrderIdList=ids
        )

# %%
def main(step):
    try:
        x = threading.Thread(target=check_positions_new(symbol))
        x.start()
        y = threading.Thread(target=get_profit(symbol))
        y.start()
        z = threading.Thread(target=check_step(symbol))
        z.start()
        w = threading.Thread(target=order_clean(symbol))
        w.start()
    except :
        print('\n\nSomething went wrong. Continuing...')

# %%
def start_stop():
    starttime=time.time()
    counterr=1
    timeout = time.time() + 60*60*6  # 60 seconds times 60 meaning the script will run for 12 hr
    while time.time() <= timeout:
        try:

            print("script continue running at "+time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
            main(counterr)
            counterr=counterr+1
            if counterr>3:
                counterr=1
            time.sleep(4 - ((time.time() - starttime) % 4.0)) # 1 minute interval between each new execution
        except KeyboardInterrupt:
            print('\n\KeyboardInterrupt. Stopping.')

# %%
start_stop()
# Out:
# script continue running at 2022-11-27 10:54:35
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:54:39
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:54:43
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:54:47
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:54:51
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:54:55
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:54:59
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:03
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:07
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:11
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:15
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:19
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:27
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:31
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:35
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:39
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:43
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:47
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:51
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:55
# Nothing to close
# -0.11468074 + 11 - 23
# script continue running at 2022-11-27 10:55:59
# Compensation LONG price 1214.48
# -0.11593073 + 12 - 23
# script continue running at 2022-11-27 10:56:07
# -0.11593073 + 12 - 23
# script continue running at 2022-11-27 10:56:11
# -0.11593073 + 12 - 23
# script continue running at 2022-11-27 10:56:15
# -0.11593073 + 12 - 23
# script continue running at 2022-11-27 10:56:19
# Direction LONG again
#
#
# Something went wrong. Continuing...
# LONG order opened price:1214.93
# SHORT order opened price:1212.27
# LONG tp order opened price:1218.6
# LONG tp order opened price:1216.6
# LONG sl order opened price:1209.4
# LONG sl order opened price:1207.8
# LONG sl order opened price:1208.6
# script continue running at 2022-11-27 10:56:23
# SHORT tp order opened price:1209.33
# SHORT tp order opened price:1207.73
# Nothing to close
# SHORT sl order opened price:1216.53
# SHORT sl order opened price:1215.73
# SHORT sl order opened price:1217.33
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:56:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:57:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:58:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 10:59:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:00:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:01:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:02:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:03:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:20:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-27 11:20:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:20:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:21:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:22:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:23:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:24:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:25:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:26:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:27:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:28:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:29:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:30:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:31:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:32:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:33:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:34:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:35:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:36:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:37:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:38:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:39:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:40:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:41:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:42:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:43:59
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:44:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:31
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:35
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:39
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:43
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:47
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:51
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:45:55
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:03
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:07
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:11
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:15
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:19
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:23
# Nothing to close
# -0.09199354000000001 + 12 - 21
# script continue running at 2022-11-27 11:46:27
# Nothing to close
# -0.09199354000000001 + 12 - 21
# ...
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:17:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:18:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:19:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:20:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:21:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:22:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:23:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:24:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:25:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:26:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:43
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:27:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:11
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:15
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:19
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:23
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:27
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:31
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:35
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:39
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:47
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:51
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:55
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:28:59
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:29:03
# Nothing to close
# -0.013269670000000003 + 11 - 22
# script continue running at 2022-11-27 13:29:07
# Nothing to close
# -0.013269670000000003 + 11 - 22
