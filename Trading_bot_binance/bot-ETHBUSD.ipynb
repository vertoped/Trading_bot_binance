# %%
import requests
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import copy
import time
import random
import threading
import coinconfig

from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
from binance.helpers import round_step_size
from futures_sign import send_signed_request, send_public_request
from cred import KEY, SECRET

# %%
#0:BTCBUSD, 1:BTCUSDT, 2:DOGEUSDT, 3:DOGEBUSD, 4:ETHBUSD, 5:ETHUSDT, 6:EOSUSDT, 7:LTCUSDT, 8:BNBBUSD

# %%
client = Client(KEY, SECRET, testnet=False)
config=coinconfig.tradeconfig
coin=coinconfig.coinlist[4]

# %%
symbol=coin["symbol"]
asset=coin["asset"]
recvWindow=config["recvWindow"]
dualSidePosition=config["dualSidePosition"]
marginType=config["marginType"]

leverage=coin["leverage"]
roundity=coin["roundity"]
profit_percent=coin["profit_percent"]
risk=coin["risk"]
stop_percent=profit_percent-risk
balance_part=coin["balance_part"]
compensation=coin["compensation"]
price_divergence=coin['price_divergence']

# %%
client.futures_change_leverage(symbol=symbol, leverage=leverage, recvWindow=recvWindow)
# Out:
# {'symbol': 'ETHBUSD', 'leverage': 50, 'maxNotionalValue': '50000'}

# %%
# Margin type
def margin_type_to_isolated():
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    body=positions[positions['symbol']==symbol]['isolated'].astype(bool).tolist()[0]

    if body==True:
        client.futures_change_margin_type(symbol=symbol, marginType=marginType, recvWindow=recvWindow)
        print(f'Changed to {marginType}')
    else:
        print(f'Already {marginType}')

# %%
margin_type_to_isolated()
# Out:
# Already CROSSED

# %%
# Hedge mode turn on

def hedge_mode_turn_on():
    status=client.futures_get_position_mode() 
    if status['dualSidePosition']==False:
        client.futures_change_position_mode(dualSidePosition=dualSidePosition, recvWindow=recvWindow)
        client.futures_get_position_mode()
        print('Dual turned on')
    else:
        print('Already Dual')
    return(status['dualSidePosition'])

# %%
hedge_mode_turn_on()
# Out:
# Already Dual
# True

# %%
def get_assetbalance(symbol):
    status = client.futures_account()
    balance = pd.DataFrame(status['assets'])
    assetbalance = float(balance.loc[balance['asset'] == asset, 'availableBalance'])
    return(assetbalance)

# %%
# Find all opened positions

def get_opened_positions(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    open_positions=positions[positions['symbol']==symbol]
    long_position=float(open_positions[open_positions['positionSide']=='LONG']['entryPrice'])
    short_position=float(open_positions[open_positions['positionSide']=='SHORT']['entryPrice'])

    return([long_position,short_position])

# %%
def get_quant(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    open_positions=positions[positions['symbol']==symbol]
    quant=float(open_positions[open_positions['positionSide']=='LONG']['positionAmt'])
    if quant==0:
        quant=abs(float(open_positions[open_positions['positionSide']=='SHORT']['positionAmt']))
    return(quant)

# %%
quant=get_quant(symbol)

# %%
# Close all orders 

def check_and_close_orders(symbol):
    global isStop 
    a=client.futures_get_open_orders(symbol=symbol)
    if len(a)>0:
        isStop = False
        client.futures_cancel_all_open_orders(symbol=symbol)

# %%
def get_symbol_price(symbol):
    prices = client.get_all_tickers()
    df=pd.DataFrame(prices)
    return float(df[ df['symbol']==symbol]['price'])

# %%
get_symbol_price(symbol)
# Out:
# 1266.56

# %%
#получить tick size

def get_tick_size(symbol):
    data = client.futures_exchange_info()
    tick_size = 0.0
    the_symbol = symbol

    found = False
    info = data['symbols']
    for s in range(len(info)):
        if info[s]['symbol'] == the_symbol:
            filters = info[s]['filters']
            for f in range(len(filters)):
                if filters[f]['filterType'] == 'PRICE_FILTER':
                    tick_size = float(filters[f]['tickSize'])
                    found = True
                    break
            break
    return(tick_size)

# %%
#Trade config

# maxposition=0.016 #1 = 100% = 1 BTC,
maxposition=round(get_assetbalance(symbol)*balance_part*leverage/get_symbol_price(symbol),3)
quantity=str(round(maxposition/2,roundity))
tick_size=get_tick_size(symbol)
symbolround=abs(str(tick_size).find('.') - len(str(tick_size))) - 1
quantity
# Out:
# '0.017'

# %%
#Stop loss LONG 
def open_sl_long(symbol,quant,tick_size):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[0]
        stop_price_trigger=str(round(float(entry_price)*(1-stop_percent), symbolround))
        stop_price=str(round(float(stop_price_trigger)*0.9999, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "positionSide": "LONG",
                    "type": "STOP",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": stop_price_trigger,
                    "price": stop_price
                }
            ]
        }

        open_position_sl_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        long_sl_opened=float(open_position_sl_long_response[0]['price'])
        print('LONG sl order opened price:'+str(long_sl_opened))
        return(long_sl_opened)
    
    except :
        print('\n\nSL long not open...')

# %%
#Take Profit LONG 

def open_tp_long(symbol,quant,tick_size):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[0]
        take_price_trigger=str(round(float(entry_price)*(1+profit_percent), symbolround))
        take_price=str(round(float(take_price_trigger)*0.9999, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "positionSide": "LONG",
                    "type": "TAKE_PROFIT",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": take_price_trigger,
                    "price": take_price
                }
            ]
        }
        open_position_tp_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        long_tp_opened=float(open_position_tp_long_response[0]['price'])
        print('LONG tp order opened price:'+str(long_tp_opened))
        return(long_tp_opened)
        
    except :
        print('\n\nTP long not open...')

# %%
#Открыть sl&tp LONG если есть позиция

def long_tp_sl_opening(symbol,quantity):
    position=get_opened_positions(symbol)
    if position[0]>0:
        orders=client.futures_get_open_orders(symbol=symbol)
        orders_df=pd.DataFrame(orders)
        if orders_df.empty:
            x = threading.Thread(target=open_tp_long, args=(symbol,quantity,tick_size))
            x.start()
            y = threading.Thread(target=open_sl_long, args=(symbol,quantity,tick_size))
            y.start()
        else:
            order_long=orders_df[orders_df['positionSide']=='LONG']
            long_tp=order_long[order_long['origType']=='TAKE_PROFIT']['price']
            long_sl=order_long[order_long['origType']=='STOP']['price']
            if (long_tp+long_sl).empty:
                x = threading.Thread(target=open_tp_long, args=(symbol,quantity,tick_size))
                x.start()
                y = threading.Thread(target=open_sl_long, args=(symbol,quantity,tick_size))
                y.start()
            else:
                print('LONG SL TP iteration continious..')

# %%
#Открыть позицию LONG 

def open_position_long(symbol,quantity,tick_size):
    sprice=get_symbol_price(symbol)
    close_price=str(round(sprice*(1+0.001),symbolround))
    tick=str(tick_size)
    params = {
        "batchOrders": [
            {
                "symbol":symbol,
                "side": "BUY",
                "positionSide": "LONG",
                "type": "LIMIT",
                "quantity": quantity,
                "timeInForce":"GTC",
                "tickSize": tick,
                "price": close_price        
            }
        ]
    }
    open_position_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
    long_opened=float(open_position_long_response[0]['price'])
    print('LONG order opened price:'+str(long_opened))
    if long_opened>0:
        long_tp_sl_opening(symbol,quantity)
    return(long_opened)

# %%
#Stop loss SHORT 

def open_sl_short(symbol,quant,tick_size):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[1]
        stop_price_trigger=str(round(float(entry_price)*(1+stop_percent), symbolround))
        stop_price=str(round(float(stop_price_trigger)*1.0001, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "positionSide": "SHORT",
                    "type": "STOP",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": stop_price_trigger,
                    "price": stop_price
                }
            ]
        }
        
        open_position_sl_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        short_sl_opened=float(open_position_sl_short_response[0]['price'])
        print('SHORT sl order opened price:'+str(short_sl_opened))
        return(short_sl_opened)
    
    except :
        print('\n\nSL short not open...')

# %%
#Take Profit SHORT

def open_tp_short(symbol,quant,tick_size):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[1]
        take_price_trigger=str(round(float(entry_price)*(1-profit_percent), symbolround))
        take_price=str(round(float(take_price_trigger)*1.0001, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "positionSide": "SHORT",
                    "type": "TAKE_PROFIT",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": take_price_trigger,
                    "price": take_price
                }
            ]
        }

        open_position_tp_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        short_tp_opened=float(open_position_tp_short_response[0]['price'])
        print('SHORT tp order opened price:'+str(short_tp_opened))
        return(short_tp_opened)
    
    except :
        print('\n\nTp short not open...')

# %%
#Открыть sl&tp SHORT если есть позиция
       
def short_tp_sl_opening(symbol,quantity):
    position=get_opened_positions(symbol)
    if position[1]>0:
        orders=client.futures_get_open_orders(symbol=symbol)
        orders_df=pd.DataFrame(orders)
        if orders_df.empty:
            x = threading.Thread(target=open_tp_short, args=(symbol,quantity,tick_size))
            x.start()
            y = threading.Thread(target=open_sl_short, args=(symbol,quantity,tick_size))
            y.start()
        else:
            order_short=orders_df[orders_df['positionSide']=='SHORT']
            short_tp=order_short[order_short['origType']=='TAKE_PROFIT']['price']
            short_sl=order_short[order_short['origType']=='STOP']['price']
            if (short_tp+short_sl).empty:
                x = threading.Thread(target=open_tp_short, args=(symbol,quantity,tick_size))
                x.start()
                y = threading.Thread(target=open_sl_short, args=(symbol,quantity,tick_size))
                y.start()
            else:
                print('SHORT SL TP iteration continious..')

# %%
#Открыть позицию SHORT

def open_position_short(symbol,quantity,tick_size):
    sprice=get_symbol_price(symbol)
    close_price=str(round(sprice*(1-0.001),symbolround))
    tick=str(tick_size)
    params = {
        "batchOrders": [
            {
                "symbol":symbol,
                "side": "SELL",
                "positionSide": "SHORT",
                "type": "LIMIT",
                "quantity": quantity,
                "timeInForce":"GTC",
                "tickSize": tick,
                "price": close_price        
            }
        ]
    }
    open_position_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
    short_opened=float(open_position_short_response[0]['price'])
    print('SHORT order opened price:'+str(short_opened))
    if short_opened>0:
        short_tp_sl_opening(symbol,quantity)
    return(short_opened)

# %%
def check_positions_ready(symbol):
    positions=get_opened_positions(symbol)
    if positions[0] and positions[1] > 0:
        orders=client.futures_get_open_orders(symbol=symbol)
        orders_df=pd.DataFrame(orders)
        if len(orders_df.index)==2:
            quant=str(get_quant(symbol))
            if orders_df['positionSide'][0]=='SHORT':
                long_tp_sl_opening(symbol,quant)
            else:
                short_tp_sl_opening(symbol,quant)
        else:
            print('TP/SL stage ок')

# %%
def check_avg(symbol):
    x = requests.get('https://binance.com/fapi/v1/klines?symbol='+symbol+'&limit='+str(50)+'&interval=1m')
    dataset=pd.DataFrame(x.json())
    dataset.columns=['open_time','open','high','low','close','volume','close_time','d1','d2','d3','d4','d5']
    dataset['open']=dataset['open'].astype(float)
    openmean=dataset['open'].mean()
    check=abs(openmean-get_symbol_price(symbol))/openmean
    print(check)
    verdict=1
    if check < price_divergence:
        verdict=0
    return(verdict)

# %%
def check_positions_new(symbol):
    positions=get_opened_positions(symbol)
    avg=check_avg(symbol)
    if avg==1:
        if positions[0]+positions[1]==0:
            x = threading.Thread(target=open_position_short, args=(symbol,quantity,tick_size))
            x.start()
            y = threading.Thread(target=open_position_long, args=(symbol,quantity,tick_size))
            y.start()
            print('Start new positions')
    else:
        print('Near average price')

# %%
def check_one_stop(symbol):
    orders=client.futures_get_open_orders(symbol=symbol)
    df=pd.DataFrame(orders)
    if len(df.index)==2:
        quant=str(get_quant(symbol))
        positions=get_opened_positions(symbol)
        price=get_symbol_price(symbol)
        if positions[0]==0: #если остался шорт, то цена закрытия не должна быть выше чем (цена входа *(1- процент компенсации) 
            compensation_price=positions[1]*(1-(stop_percent*compensation))
            print('SHORT compansation stage')
            if price > compensation_price: #если шорт отрос на 0.4
                params={ 
                    "batchOrders": [
                        {
                            "symbol":symbol, 
                            "positionSide": "SHORT", 
                            "side":'BUY', 
                            "type":'MARKET',
                            "quantity":quant
                        }
                    ]
                }
                one_stop=send_signed_request('POST', '/fapi/v1/batchOrders', params)
                if str(float(one_stop[0]['origQty']))==quant:
                    print(f'Compensation SHORT price {compensation_price}')
            else:
                print('One step for SHORT not in compensation condition')
        if positions[1]==0:
            compensation_price=positions[0]*(1+(stop_percent*compensation))
            print('LONG compansation stage')
            if price < compensation_price: #если лонг упал на 0.4
                params={ 
                    "batchOrders": [
                        {
                            "symbol":symbol, 
                            "positionSide": "LONG", 
                            "side":'SELL', 
                            "type":'MARKET',
                            "quantity":quant
                        }
                    ]
                }
                one_stop=send_signed_request('POST', '/fapi/v1/batchOrders', params)
                if str(float(one_stop[0]['origQty']))==quant:
                    print(f'Compensation LONG price {compensation_price}')
            else:
                print('One step for LONG not in compensation condition')

# %%
def main(step):
    #getTPSLfrom_telegram()
    try:
        x = threading.Thread(target=check_positions_new(symbol))
        x.start()
        y = threading.Thread(target=check_positions_ready(symbol))
        y.start()
        z = threading.Thread(target=check_one_stop(symbol))
        z.start()
    except :
        print('\n\nSomething went wrong. Continuing...')

# %%
telegram_delay=12
bot_token='5454990445:AAGzfeY80oeI-1su0MEIRVuvTzBYIVlZIXU'
chat_id='92428939'

def getTPSLfrom_telegram():
    strr='https://api.telegram.org/bot'+bot_token+'/getUpdates'
    response = requests.get(strr)
    rs=response.json()
    exit=0

    if(len(rs['result'])>0):
        rs2=rs['result'][-1]
        rs3=rs2['message']
        textt=rs3['text']
        datet=rs3['date']        
        if(time.time()-datet)<telegram_delay:
            if 'exit' in textt:
                exit=1
                telegram_bot_sendtext('Right now! Sir')
            if 'profit' in textt:
                trades = client.futures_account_trades(symbol=symbol)
                dataset=pd.DataFrame(trades).iloc[-50:]
                bnbdata=dataset[dataset['commissionAsset']=='BNB']
                busddata=dataset[dataset['commissionAsset']=='BUSD']
                bnbcom=bnbdata['commission'].astype(float).sum()
                busdcom=busddata['commission'].astype(float).sum()
                com=(bnbcom*270+busdcom)*-1
                real=dataset['realizedPnl'].astype(float).sum()
                profit=com+real
                telegram_bot_sendtext('Profit = ' + str(profit))

    return(exit)

# %%
trades = client.futures_account_trades(symbol=symbol)
dataset=pd.DataFrame(trades).iloc[-30:]
bnbdata=dataset[dataset['commissionAsset']=='BNB']
busddata=dataset[dataset['commissionAsset']==asset]
bnbcom=bnbdata['commission'].astype(float).sum()
busdcom=busddata['commission'].astype(float).sum()
com=(bnbcom*270+busdcom)*-1
real=dataset['realizedPnl'].astype(float).sum()
profit=com+real
profit
# Out:
# -0.31278711000000003

# %%
def telegram_bot_sendtext(bot_message):
    bot_token2 = bot_token
    bot_chatID = chat_id
    send_text = 'https://api.telegram.org/bot' + bot_token2 + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message
    response = requests.get(send_text)
    return response.json()

# %%
def prt(message):
    # telegram message
    telegram_bot_sendtext(pointer+': '+message)
    print(pointer+': '+message)

# %%
def start_stop():
    starttime=time.time()
    counterr=1
    timeout = time.time() + 60*60*2  # 60 seconds times 60 meaning the script will run for 12 hr
        
    while time.time() <= timeout:
        try:

            print("script continue running at "+time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
            main(counterr)
            counterr=counterr+1
            # stop=getTPSLfrom_telegram()
            # if stop==1:
            #     break
            if counterr>3:
                # break
                counterr=1
            time.sleep(7 - ((time.time() - starttime) % 7.0)) # 1 minute interval between each new execution
        except KeyboardInterrupt:
            print('\n\KeyboardInterrupt. Stopping.')

# %%
start_stop()
# Out:
# script continue running at 2022-11-12 18:30:55
# 0.0011923613170231428
# Near average price
# script continue running at 2022-11-12 18:31:02
# 0.0009176774841569835
# Near average price
# script continue running at 2022-11-12 18:31:09
# 8.17045267779033e-05
# Near average price
# script continue running at 2022-11-12 18:31:16
# 0.00021577566145194224
# Near average price
# script continue running at 2022-11-12 18:31:23
# 0.0002394352734532116
# Near average price
# script continue running at 2022-11-12 18:31:30
# 0.0004918044681337766
# Near average price
# script continue running at 2022-11-12 18:31:37
# 0.0004839179308000201
# Near average price
# script continue running at 2022-11-12 18:31:44
# 0.0007047409761453801
# Near average price
# script continue running at 2022-11-12 18:31:51
# 0.0004918044681337766
# Near average price
# script continue running at 2022-11-12 18:31:58
# 0.000381392945461007
# Near average price
# script continue running at 2022-11-12 18:32:05
# 0.00029449960856979784
# Near average price
# script continue running at 2022-11-12 18:32:12
# 0.0006257525159056401
# Near average price
# script continue running at 2022-11-12 18:32:19
# 0.0006967352817632437
# Near average price
# script continue running at 2022-11-12 18:32:26
# 0.0007125092297316
# Near average price
# script continue running at 2022-11-12 18:32:33
# 0.0007125092297316
# Near average price
# script continue running at 2022-11-12 18:32:40
# 0.0002629517126330851
# Near average price
# script continue running at 2022-11-12 18:32:47
# 0.0004049172443482924
# Near average price
# script continue running at 2022-11-12 18:32:54
# 0.0004049172443482924
# Near average price
# script continue running at 2022-11-12 18:33:01
# 0.00019545395245304555
# Near average price
# script continue running at 2022-11-12 18:33:08
# 4.9060677330644766e-05
# Near average price
# script continue running at 2022-11-12 18:33:15
# 0.00032954262039874355
# Near average price
# script continue running at 2022-11-12 18:33:22
# 0.0003058799142906792
# Near average price
# script continue running at 2022-11-12 18:33:36
# 8.502799061523257e-05
# Near average price
# script continue running at 2022-11-12 18:33:43
# 0.0003058799142906792
# Near average price
# script continue running at 2022-11-12 18:33:50
# 0.0002979923455879911
# Near average price
# script continue running at 2022-11-12 18:33:57
# 0.0007949091738578805
# Near average price
# script continue running at 2022-11-12 18:34:04
# 0.0007219401004280372
# Near average price
# script continue running at 2022-11-12 18:34:11
# 0.000785046752563288
# Near average price
# script continue running at 2022-11-12 18:34:18
# 0.0008402650731816325
# Near average price
# script continue running at 2022-11-12 18:34:25
# 0.0012267933175104026
# Near average price
# script continue running at 2022-11-12 18:34:32
# 0.0009585900459354072
# Near average price
# script continue running at 2022-11-12 18:34:39
# 0.0010611383556553692
# Near average price
# script continue running at 2022-11-12 18:34:46
# 0.0010690266871722755
# Near average price
# script continue running at 2022-11-12 18:34:53
# 0.0016764282139746028
# Near average price
# script continue running at 2022-11-12 18:35:00
# 0.001568987813521509
# Near average price
# script continue running at 2022-11-12 18:35:07
# 0.0018608851842992458
# Near average price
# script continue running at 2022-11-12 18:35:14
# 0.0017504375304915212
# Near average price
# script continue running at 2022-11-12 18:35:21
# 0.0013796489784223735
# Near average price
# script continue running at 2022-11-12 18:35:28
# 0.001024638662611472
# Near average price
# script continue running at 2022-11-12 18:35:35
# 0.001292868679001839
# Near average price
# script continue running at 2022-11-12 18:35:42
# 0.0008510780637705828
# Near average price
# script continue running at 2022-11-12 18:35:49
# 0.000906301890674445
# Near average price
# script continue running at 2022-11-12 18:35:56
# 0.0015453204591341395
# Near average price
# script continue running at 2022-11-12 18:36:03
# 0.00135124622205732
# Near average price
# script continue running at 2022-11-12 18:36:10
# 0.0015484969259661819
# Near average price
# script continue running at 2022-11-12 18:36:17
# 0.0017694177143440857
# Near average price
# script continue running at 2022-11-12 18:36:24
# 0.0019035481930021693
# Near average price
# script continue running at 2022-11-12 18:36:31
# 0.0019193282493148638
# Near average price
# script continue running at 2022-11-12 18:36:38
# 0.0019666684182529474
# Near average price
# script continue running at 2022-11-12 18:36:45
# 0.0020613487561292948
# Near average price
# script continue running at 2022-11-12 18:36:52
# 0.0019824484745656424
# Near average price
# script continue running at 2022-11-12 18:36:59
# 0.0019824484745656424
# Near average price
# script continue running at 2022-11-12 18:37:06
# 0.0018606956066119773
# Near average price
# script continue running at 2022-11-12 18:37:13
# 0.0017896766903291404
# Near average price
# script continue running at 2022-11-12 18:37:20
# 0.001458255081008876
# Near average price
# script continue running at 2022-11-12 18:37:27
# 0.0015766199414804503
# Near average price
# script continue running at 2022-11-12 18:37:34
# 0.001189961397273535
# Near average price
# script continue running at 2022-11-12 18:37:41
# 0.001197852387971628
# Near average price
# script continue running at 2022-11-12 18:37:48
# 0.001197852387971628
# Near average price
# script continue running at 2022-11-12 18:37:55
# 0.0010637055461038677
# Near average price
# script continue running at 2022-11-12 18:38:02
# 0.0008777508238877889
# Near average price
# script continue running at 2022-11-12 18:38:09
# 0.000522609778437749
# Near average price
# script continue running at 2022-11-12 18:38:16
# 0.0008698588006555737
# Near average price
# script continue running at 2022-11-12 18:38:23
# 0.0005778539410634343
# Near average price
# script continue running at 2022-11-12 18:38:30
# 0.0005147177552055339
# Near average price
# script continue running at 2022-11-12 18:38:37
# 0.00038844538349009174
# Near average price
# script continue running at 2022-11-12 18:38:44
# 0.00038055336025787664
# Near average price
# script continue running at 2022-11-12 18:38:51
# 0.0005068257319733188
# Near average price
# script continue running at 2022-11-12 18:38:58
# 0.0005068257319733188
# Near average price
# script continue running at 2022-11-12 18:39:05
# 0.0006222728206955578
# Near average price
# script continue running at 2022-11-12 18:39:12
# 0.0006222728206955578
# Near average price
# script continue running at 2022-11-12 18:39:19
# 0.0006222728206955578
# Near average price
# script continue running at 2022-11-12 18:39:26
# 0.0003302371235148777
# Near average price
# script continue running at 2022-11-12 18:39:33
# 0.00033812998019543177
# Near average price
# script continue running at 2022-11-12 18:39:40
# 0.0003302371235148777
# Near average price
# script continue running at 2022-11-12 18:39:47
# 0.0003302371235148777
# Near average price
# script continue running at 2022-11-12 18:39:54
# 0.00033812998019543177
# Near average price
# script continue running at 2022-11-12 18:40:01
# 0.00047676406651335636
# Near average price
# script continue running at 2022-11-12 18:40:08
# 0.0008477559725750699
# Near average price
# script continue running at 2022-11-12 18:40:15
# 0.0008872231966241501
# Near average price
# script continue running at 2022-11-12 18:40:22
# 0.0013371495507840242
# Near average price
# script continue running at 2022-11-12 18:40:29
# 0.0011477068753482594
# Near average price
# script continue running at 2022-11-12 18:40:36
# 0.0012740019923054959
# Near average price
# script continue running at 2022-11-12 18:40:43
# 0.0012345347682564155
# Near average price
# script continue running at 2022-11-12 18:40:50
# 0.0008477559725750699
# Near average price
# script continue running at 2022-11-12 18:40:57
# 0.0012108544338269673
# Near average price
# script continue running at 2022-11-12 18:41:04
# 0.0012299113169210061
# Near average price
# script continue running at 2022-11-12 18:41:11
# 0.001143075472979306
# Near average price
# script continue running at 2022-11-12 18:41:18
# 0.0010562396290374266
# Near average price
# script continue running at 2022-11-12 18:41:25
# 0.0011036046348239879
# Near average price
# script continue running at 2022-11-12 18:41:32
# 0.0011114988024550517
# Near average price
# script continue running at 2022-11-12 18:41:39
# 0.0011114988024550517
# Near average price
# script continue running at 2022-11-12 18:41:46
# 0.001166757975872497
# Near average price
# script continue running at 2022-11-12 18:41:53
# 0.0015614663574260376
# Near average price
# script continue running at 2022-11-12 18:42:00
# 0.0011302596628675408
# Near average price
# script continue running at 2022-11-12 18:42:07
# 0.0012960563443443539
# Near average price
# script continue running at 2022-11-12 18:42:14
# 0.001501328426172746
# Near average price
# script continue running at 2022-11-12 18:42:21
# 0.0015250136663836936
# Near average price
# script continue running at 2022-11-12 18:42:28
# 0.0014618530258211668
# Near average price
# script continue running at 2022-11-12 18:42:35
# 0.0012723711041334061
# Near average price
# script continue running at 2022-11-12 18:42:42
# 0.0012723711041334061
# Near average price
# script continue running at 2022-11-12 18:42:49
# 0.0015881743069464003
# Near average price
# script continue running at 2022-11-12 18:42:56
# 0.0016592300275792432
# Near average price
# script continue running at 2022-11-12 18:43:03
# 0.0015498283881691926
# Near average price
# script continue running at 2022-11-12 18:43:10
# 0.0015498283881691926
# Near average price
# script continue running at 2022-11-12 18:43:17
# 0.0015498283881691926
# Near average price
# script continue running at 2022-11-12 18:43:24
# 0.0015498283881691926
# Near average price
# script continue running at 2022-11-12 18:43:31
# 0.0014708683113316345
# Near average price
# script continue running at 2022-11-12 18:43:38
# 0.0014787643190153903
# Near average price
# script continue running at 2022-11-12 18:43:45
# 0.001581412418904216
# Near average price
# script continue running at 2022-11-12 18:43:52
# 0.0013603242037588737
# Near average price
# script continue running at 2022-11-12 18:43:59
# 0.0011866120347160663
# Near average price
# script continue running at 2022-11-12 18:44:06
# 0.0010305329948238741
# Near average price
# script continue running at 2022-11-12 18:44:13
# 0.00065938318059618
# Near average price
# script continue running at 2022-11-12 18:44:20
# 0.000311923780042571
# Near average price
# script continue running at 2022-11-12 18:44:27
# 0.000311923780042571
# Near average price
# script continue running at 2022-11-12 18:44:34
# 0.0003435109982746846
# Near average price
# script continue running at 2022-11-12 18:44:41
# 0.0003435109982746846
# Near average price
# script continue running at 2022-11-12 18:44:48
# 0.00015398768888146418
# Near average price
# script continue running at 2022-11-12 18:44:55
# 0.00016188449343949258
# Near average price
# script continue running at 2022-11-12 18:45:02
# 0.0005409311122252153
# Near average price
# script continue running at 2022-11-12 18:45:09
# 0.0008317493872441244
# Near average price
# script continue running at 2022-11-12 18:45:16
# 0.0009423123517468579
# Near average price
# script continue running at 2022-11-12 18:45:23
# 0.0003263186923749467
# Near average price
# script continue running at 2022-11-12 18:45:30
# 0.0001870093571017358
# Near average price
# script continue running at 2022-11-12 18:45:37
# 0.00019490671170906108
# Near average price
# script continue running at 2022-11-12 18:45:44
# 0.00014752258406510935
# Near average price
# script continue running at 2022-11-12 18:45:51
# 0.00016047424562093607
# Near average price
# script continue running at 2022-11-12 18:45:58
# 0.0002868319193381407
# Near average price
# script continue running at 2022-11-12 18:46:05
# 0.0006798459479190668
# Near average price
# script continue running at 2022-11-12 18:46:12
# 0.0006956416251476566
# Near average price
# script continue running at 2022-11-12 18:46:19
# 0.0007588243340621955
# Near average price
# script continue running at 2022-11-12 18:46:26
# 0.0005218891756329888
# Near average price
# script continue running at 2022-11-12 18:46:33
# 0.0006087654003904125
# Near average price
# script continue running at 2022-11-12 18:46:40
# 0.000664050270690477
# Near average price
# script continue running at 2022-11-12 18:46:47
# 0.0007035394637619516
# Near average price
# script continue running at 2022-11-12 18:46:54
# 0.0008220070429765549
# Near average price
# script continue running at 2022-11-12 18:47:01
# 0.0013324139913735854
# Near average price
# script continue running at 2022-11-12 18:47:08
# 0.001182349582149478
# Near average price
# script continue running at 2022-11-12 18:47:15
# 0.0013166177377710666
# Near average price
# script continue running at 2022-11-12 18:47:22
# 0.0015851540490142441
# Near average price
# script continue running at 2022-11-12 18:47:29
# 0.0015930521758155034
# Near average price
# script continue running at 2022-11-12 18:47:36
# 0.001648339063424319
# Near average price
# script continue running at 2022-11-12 18:47:43
# 0.0018694866138597606
# Near average price
# script continue running at 2022-11-12 18:47:50
# 0.001837894106654723
# Near average price
# script continue running at 2022-11-12 18:47:57
# 0.0022643929539230877
# Near average price
# script continue running at 2022-11-12 18:48:04
# 0.0014302196857878115
# Near average price
# script continue running at 2022-11-12 18:48:11
# 0.0017540489718341611
# Near average price
# script continue running at 2022-11-12 18:48:18
# 0.0018409299997979474
# Near average price
# script continue running at 2022-11-12 18:48:25
# 0.0018409299997979474
# Near average price
# script continue running at 2022-11-12 18:48:32
# 0.0011616783266272137
# Near average price
# script continue running at 2022-11-12 18:48:39
# 0.0013038472814769313
# Near average price
# script continue running at 2022-11-12 18:48:46
# 0.0011774748771660514
# Near average price
# script continue running at 2022-11-12 18:48:53
# 0.0013117455567463502
# Near average price
# script continue running at 2022-11-12 18:49:00
# 0.0013038472814769313
# Near average price
# script continue running at 2022-11-12 18:49:07
# 0.0013993366973442578
# Near average price
# script continue running at 2022-11-12 18:49:14
# 0.0013993366973442578
# Near average price
# script continue running at 2022-11-12 18:49:21
# 0.001731082809832787
# Near average price
# script continue running at 2022-11-12 18:49:28
# 0.0019759430357170924
# Near average price
# script continue running at 2022-11-12 18:49:35
# 0.002047031488393129
# Near average price
# script continue running at 2022-11-12 18:49:42
# 0.0017784751116168116
# Near average price
# script continue running at 2022-11-12 18:49:49
# 0.0017942725455448196
# Near average price
# script continue running at 2022-11-12 18:49:56
# 0.0017942725455448196
# Near average price
# script continue running at 2022-11-12 18:50:03
# 0.0019017792173036331
# Near average price
# script continue running at 2022-11-12 18:50:10
# 0.0016727062928068661
# Near average price
# script continue running at 2022-11-12 18:50:17
# 0.0016569081600829759
# Near average price
# script continue running at 2022-11-12 18:50:24
# 0.0014357343019483337
# Near average price
# script continue running at 2022-11-12 18:50:31
# 0.0016174128282732505
# Near average price
# script continue running at 2022-11-12 18:50:38
# 0.000898597789335528
# Near average price
# script continue running at 2022-11-12 18:50:45
# 0.0011592669792800756
# Near average price
# script continue running at 2022-11-12 18:50:52
# 0.0012461567092614716
# Near average price
# script continue running at 2022-11-12 18:50:59
# 0.000976543213972652
# Near average price
# script continue running at 2022-11-12 18:51:06
# 0.0009133467594200231
# Near average price
# script continue running at 2022-11-12 18:51:13
# 0.0004788711343715755
# Near average price
# script continue running at 2022-11-12 18:51:20
# 8.989695660100629e-05
# Near average price
# script continue running at 2022-11-12 18:51:27
# 0.0006052640434766536
# Near average price
# script continue running at 2022-11-12 18:51:34
# 0.0006052640434766536
# Near average price
# script continue running at 2022-11-12 18:51:41
# 0.00045517246391440705
# Near average price
# script continue running at 2022-11-12 18:51:48
# 0.0005025698048287439
# Near average price
# script continue running at 2022-11-12 18:51:55
# 0.0006131636002957097
# Near average price
# script continue running at 2022-11-12 18:52:02
# 0.0011470843359787887
# Near average price
# script continue running at 2022-11-12 18:52:09
# 0.0018185868742583114
# Near average price
# script continue running at 2022-11-12 18:52:16
# 0.0018817871131553367
# Near average price
# script continue running at 2022-11-12 18:52:23
# 0.0014156853512905618
# Near average price
# script continue running at 2022-11-12 18:52:30
# 0.0013208849929452935
# Near average price
# script continue running at 2022-11-12 18:52:37
# 0.0009495835894259666
# Near average price
# script continue running at 2022-11-12 18:52:44
# 0.00110758418666826
# Near average price
# script continue running at 2022-11-12 18:52:51
# 0.0015894860082570667
# Near average price
# script continue running at 2022-11-12 18:52:58
# 0.0015973860381191724
# Near average price
# script continue running at 2022-11-12 18:53:05
# 0.0015797493763480904
# Near average price
# script continue running at 2022-11-12 18:53:12
# 0.0013348392409870916
# Near average price
# script continue running at 2022-11-12 18:53:19
# 0.0013190385870928453
# Near average price
# script continue running at 2022-11-12 18:53:26
# 0.00125583597151568
# Near average price
# script continue running at 2022-11-12 18:53:33
# 0.0010504274708902975
# Near average price
# script continue running at 2022-11-12 18:53:40
# 0.0010425271439431743
# Near average price
# script continue running at 2022-11-12 18:53:47
# 0.0010504274708902975
# Near average price
# script continue running at 2022-11-12 18:53:54
# 0.0010504274708902975
# Near average price
# script continue running at 2022-11-12 18:54:01
# 0.0010985142247479198
# Near average price
# script continue running at 2022-11-12 18:54:08
# 0.0010985142247479198
# Near average price
# script continue running at 2022-11-12 18:54:15
# 0.0010906135182983591
# Near average price
# script continue running at 2022-11-12 18:54:22
# 0.0010906135182983591
# Near average price
# script continue running at 2022-11-12 18:54:29
# 0.0010985142247479198
# Near average price
# script continue running at 2022-11-12 18:54:36
# 0.0010985142247479198
# Near average price
# script continue running at 2022-11-12 18:54:43
# 0.0010985142247479198
# Near average price
# script continue running at 2022-11-12 18:54:50
# 0.0010985142247479198
# Near average price
# script continue running at 2022-11-12 18:54:57
# 0.0010906135182983591
# Near average price
# script continue running at 2022-11-12 18:55:04
# 0.00116970375616824
# Near average price
# script continue running at 2022-11-12 18:55:11
# 0.0008931593663690388
# Near average price
# script continue running at 2022-11-12 18:55:18
# 0.00070352892764953
# Near average price
# script continue running at 2022-11-12 18:55:25
# 0.000916863171208955
# Near average price
# script continue running at 2022-11-12 18:55:32
# 0.0007904428787292226
# Near average price
# script continue running at 2022-11-12 18:55:39
# 0.00070352892764953
# Near average price
# script continue running at 2022-11-12 18:55:46
# 0.0008457517566892065
# Near average price
# script continue running at 2022-11-12 18:55:53
# 0.0009563695126088151
# Near average price
# script continue running at 2022-11-12 18:56:00
# 0.0009563695126088151
# Near average price
# script continue running at 2022-11-12 18:56:07
# 0.0012358399919086289
# Near average price
# script continue running at 2022-11-12 18:56:14
# 0.0012279382016790416
# Near average price
# script continue running at 2022-11-12 18:56:21
# 0.0012279382016790416
# Near average price
# script continue running at 2022-11-12 18:56:28
# 0.0012358399919086289
# Near average price
# script continue running at 2022-11-12 18:56:35
# 0.0012358399919086289
# Near average price
# script continue running at 2022-11-12 18:56:42
# 0.0006511075149186347
# Near average price
# script continue running at 2022-11-12 18:56:49
# 0.0006511075149186347
# Near average price
# script continue running at 2022-11-12 18:56:56
# 0.0005562860321635879
# Near average price
# script continue running at 2022-11-12 18:57:03
# 0.0002776880862646178
# Near average price
# script continue running at 2022-11-12 18:57:10
# 5.642267888262474e-05
# Near average price
# script continue running at 2022-11-12 18:57:17
# 8.803202279431236e-05
# Near average price
# script continue running at 2022-11-12 18:57:24
# 0.000712316565050682
# Near average price
# script continue running at 2022-11-12 18:57:31
# 0.000720218901028604
# Near average price
# script continue running at 2022-11-12 18:57:38
# 0.0009335819724328548
# Near average price
# script continue running at 2022-11-12 18:57:45
# 0.0007834375888521589
# Near average price
# script continue running at 2022-11-12 18:57:52
# 0.0009098749644989093
# Near average price
# script continue running at 2022-11-12 18:57:59
# 0.0008229492687417683
# Near average price
# script continue running at 2022-11-12 18:58:06
# 0.000945943703310421
# Near average price
# script continue running at 2022-11-12 18:58:13
# 0.0012462432916629925
# Near average price
# script continue running at 2022-11-12 18:58:20
# 0.001609763845984451
# Near average price
# script continue running at 2022-11-12 18:58:27
# 0.001657179570461116
# Near average price
# script continue running at 2022-11-12 18:58:34
# 0.0018310372268757345
# Near average price
# script continue running at 2022-11-12 18:58:41
# 0.0017915241231451803
# Near average price
# script continue running at 2022-11-12 18:58:48
# 0.0017915241231451803
# Near average price
# script continue running at 2022-11-12 18:58:55
# 0.0017915241231451803
# Near average price
# script continue running at 2022-11-12 18:59:02
# 0.0018163834244425564
# Near average price
# script continue running at 2022-11-12 18:59:09
# 0.0019112172266235845
# Near average price
# script continue running at 2022-11-12 18:59:16
# 0.0019586341277140983
# Near average price
# script continue running at 2022-11-12 18:59:23
# 0.0012473806113558494
# Near average price
# script continue running at 2022-11-12 18:59:30
# 0.0012473806113558494
# Near average price
# script continue running at 2022-11-12 18:59:37
# 0.0011525468091746417
# Near average price
# script continue running at 2022-11-12 18:59:44
# 0.0011841580765683177
# Near average price
# script continue running at 2022-11-12 18:59:51
# 0.0010577130069936136
# Near average price
# script continue running at 2022-11-12 18:59:58
# 0.0012394777945074302
# Near average price
# script continue running at 2022-11-12 19:00:05
# 0.0015519985913626905
# Near average price
# script continue running at 2022-11-12 19:00:12
# 0.0015519985913626905
# Near average price
# script continue running at 2022-11-12 19:00:19
# 0.0015519985913626905
# Near average price
# script continue running at 2022-11-12 19:00:26
# 0.001259586187449888
# Near average price
# script continue running at 2022-11-12 19:00:33
# 0.001243780111562719
# Near average price
# script continue running at 2022-11-12 19:00:40
# 0.0012200709977319658
# Near average price
# script continue running at 2022-11-12 19:00:47
# 0.0014097439083779917
# Near average price
# script continue running at 2022-11-12 19:00:54
# 0.0015519985913626905
# Near average price
# script continue running at 2022-11-12 19:01:01
# 0.0018973418563034755
# Near average price
# script continue running at 2022-11-12 19:01:08
# 0.0016207383700880427
# Near average price
# script continue running at 2022-11-12 19:01:15
# 0.0017234768078251367
# Near average price
# script continue running at 2022-11-12 19:01:22
# 0.001731379764574144
# Near average price
# script continue running at 2022-11-12 19:01:29
# 0.0019210507265504972
# Near average price
# script continue running at 2022-11-12 19:01:36
# 0.0019289536832995044
# Near average price
# script continue running at 2022-11-12 19:01:43
# 0.0019210507265504972
# Near average price
# script continue running at 2022-11-12 19:01:50
# 0.0016760590673310933
# Near average price
# script continue running at 2022-11-12 19:01:57
# 0.0016207383700880427
# Near average price
# script continue running at 2022-11-12 19:02:04
# 0.0011208912507896557
# Near average price
# script continue running at 2022-11-12 19:02:11
# 0.0011208912507896557
# Near average price
# script continue running at 2022-11-12 19:02:18
# 0.001033963700319599
# Near average price
# script continue running at 2022-11-12 19:02:25
# 0.000765278544321062
# Near average price
# script continue running at 2022-11-12 19:02:32
# 0.000765278544321062
# Near average price
# script continue running at 2022-11-12 19:02:39
# 0.0006783509938508255
# Near average price
# script continue running at 2022-11-12 19:02:46
# 0.00026742075526474325
# Near average price
# script continue running at 2022-11-12 19:02:53
# 0.00013307817726538495
# Near average price
# script continue running at 2022-11-12 19:03:00
# 9.356565432445007e-05
# Near average price
# script continue running at 2022-11-12 19:03:07
# 1.770040733067228e-05
# Near average price
# script continue running at 2022-11-12 19:03:14
# 2.9711398019169504e-05
# Near average price
# script continue running at 2022-11-12 19:03:21
# 4.551533313578343e-05
# Near average price
# script continue running at 2022-11-12 19:03:28
# 3.761336557747647e-05
# Near average price
# script continue running at 2022-11-12 19:03:35
# 0.00015203385582207034
# Near average price
# script continue running at 2022-11-12 19:03:42
# 0.000373288947454845
# Near average price
# script continue running at 2022-11-12 19:03:49
# 0.00036538697989653803
# Near average price
# script continue running at 2022-11-12 19:03:56
# 0.00042860272036299374
# Near average price
# script continue running at 2022-11-12 19:04:03
# 0.00038402154313455113
# Near average price
# script continue running at 2022-11-12 19:04:10
# 0.00035241483176548776
# Near average price
# script continue running at 2022-11-12 19:04:17
# 0.00035241483176548776
# Near average price
# script continue running at 2022-11-12 19:04:24
# 0.0003998248988190828
# Near average price
# script continue running at 2022-11-12 19:04:31
# 0.00044723496587267787
# Near average price
# script continue running at 2022-11-12 19:04:38
# 7.585610728600362e-05
# Near average price
# script continue running at 2022-11-12 19:04:45
# 8.375778512826946e-05
# Near average price
# script continue running at 2022-11-12 19:04:52
# 8.375778512826946e-05
# Near average price
# script continue running at 2022-11-12 19:04:59
# 8.375778512826946e-05
# Near average price
# script continue running at 2022-11-12 19:05:06
# 0.00043538348118701153
# Near average price
# script continue running at 2022-11-12 19:05:13
# 0.0005776140195059443
# Near average price
# script continue running at 2022-11-12 19:05:20
# 0.000830468309850574
# Near average price
# script continue running at 2022-11-12 19:05:27
# 0.0007830581304109896
# Near average price
# script continue running at 2022-11-12 19:05:34
# 0.00082256661327731
# Near average price
# script continue running at 2022-11-12 19:05:41
# 0.000830468309850574
# Near average price
# script continue running at 2022-11-12 19:05:48
# 0.0008778784892901583
# Near average price
# script continue running at 2022-11-12 19:05:55
# 0.0008699767927168942
# Near average price
# script continue running at 2022-11-12 19:06:02
# 0.0005509122924239911
# Near average price
# script continue running at 2022-11-12 19:06:09
# 0.0005351087269499918
# Near average price
# script continue running at 2022-11-12 19:06:16
# 0.0005114033787388131
# Near average price
# script continue running at 2022-11-12 19:06:23
# 0.0003261855913838713
# Near average price
# script continue running at 2022-11-12 19:06:30
# 0.00013654280569569936
# Near average price
# script continue running at 2022-11-12 19:06:37
# 0.00018395350211769743
# Near average price
# script continue running at 2022-11-12 19:06:44
# 0.00046051589791286574
# Near average price
# script continue running at 2022-11-12 19:06:51
# 0.0005632390734940412
# Near average price
# script continue running at 2022-11-12 19:06:58
# 0.0007133729454972148
# Near average price
# script continue running at 2022-11-12 19:07:05
# 0.0006983490737118528
# Near average price
# script continue running at 2022-11-12 19:07:12
# 0.0007457590583493944
# Near average price
# script continue running at 2022-11-12 19:07:19
# 0.0010144156379623093
# Near average price
# script continue running at 2022-11-12 19:07:26
# 0.0009037923404747124
# Near average price
# script continue running at 2022-11-12 19:07:33
# 0.0007062507378181097
# Near average price
# script continue running at 2022-11-12 19:07:40
# 0.0006983490737118528
# Near average price
# script continue running at 2022-11-12 19:07:47
# 0.0006983490737118528
# Near average price
# script continue running at 2022-11-12 19:07:54
# 0.0007062507378181097
# Near average price
# script continue running at 2022-11-12 19:08:01
# 0.0004406050765670584
# Near average price
# script continue running at 2022-11-12 19:08:08
# 0.00012453256826947266
# Near average price
# script continue running at 2022-11-12 19:08:15
# 0.00011663075556203751
# Near average price
# script continue running at 2022-11-12 19:08:22
# 0.0003299796986629663
# Near average price
# script continue running at 2022-11-12 19:08:29
# 0.0003299796986629663
# Near average price
# script continue running at 2022-11-12 19:08:36
# 0.0007171685213276481
# Near average price
# script continue running at 2022-11-12 19:08:43
# 0.0007171685213276481
# Near average price
# script continue running at 2022-11-12 19:08:50
# 0.0007171685213276481
# Near average price
# script continue running at 2022-11-12 19:08:57
# 0.0008910084008914011
# Near average price
# script continue running at 2022-11-12 19:09:04
# 0.0008935392403431985
# Near average price
# script continue running at 2022-11-12 19:09:11
# 0.0006801897577710209
# Near average price
# script continue running at 2022-11-12 19:09:18
# 0.0006406805943315825
# Near average price
# script continue running at 2022-11-12 19:09:25
# 0.00039572378100799775
# Near average price
# script continue running at 2022-11-12 19:09:32
# 0.00027719629069022114
# Near average price
# script continue running at 2022-11-12 19:09:39
# 0.00027719629069022114
# Near average price
# script continue running at 2022-11-12 19:09:46
# 0.00027719629069022114
# Near average price
# script continue running at 2022-11-12 19:09:53
# 0.0002060797964993755
# Near average price
# script continue running at 2022-11-12 19:10:00
# 0.0002613926253143379
# Near average price
# script continue running at 2022-11-12 19:10:07
# 0.0002694525372392845
# Near average price
# script continue running at 2022-11-12 19:10:14
# 0.0006250350643880463
# Near average price
# script continue running at 2022-11-12 19:10:21
# 0.0006882497358812754
# Near average price
# script continue running at 2022-11-12 19:10:28
# 0.0007198570716278001
# Near average price
# script continue running at 2022-11-12 19:10:35
# 0.0007198570716278001
# Near average price
# script continue running at 2022-11-12 19:10:42
# 0.0007277589055644313
# Near average price
# script continue running at 2022-11-12 19:10:49
# 0.0009253047539803901
# Near average price
# script continue running at 2022-11-12 19:10:56
# 0.0010991451005864556
# Near average price
# script continue running at 2022-11-12 19:11:03
# 0.0011432245062832835
# Near average price
# script continue running at 2022-11-12 19:11:10
# 0.0006849232803749722
# Near average price
# script continue running at 2022-11-12 19:11:17
# 0.0006770215351006971
# Near average price
# script continue running at 2022-11-12 19:11:24
# 0.0006217093181805922
# Near average price
# script continue running at 2022-11-12 19:11:31
# 0.0005347901201635669
# Near average price
# script continue running at 2022-11-12 19:11:38
# 0.00044787092214636177
# Near average price
# script continue running at 2022-11-12 19:11:45
# 0.000566397101260667
# Near average price
# script continue running at 2022-11-12 19:11:52
# 0.0005110848843407418
# Near average price
# script continue running at 2022-11-12 19:11:59
# 0.0005110848843407418
# Near average price
# script continue running at 2022-11-12 19:12:06
# 0.0004952735667410607
# Near average price
# script continue running at 2022-11-12 19:12:13
# 0.0006612075951641662
# Near average price
# script continue running at 2022-11-12 19:12:20
# 0.0006137978727574363
# Near average price
# script continue running at 2022-11-12 19:12:27
# 0.0005663881503508861
# Near average price
# script continue running at 2022-11-12 19:12:34
# 0.0005031751871421524
# Near average price
# script continue running at 2022-11-12 19:12:41
# 0.000234520093504675
# Near average price
# script continue running at 2022-11-12 19:12:48
# 0.00017920875069703303
# Near average price
# script continue running at 2022-11-12 19:12:55
# 0.00012389740788939108
# Near average price
# script continue running at 2022-11-12 19:13:02
# 4.488001233889543e-05
# Near average price
# script continue running at 2022-11-12 19:13:10
# 1.3274369846781341e-05
# Near average price
# script continue running at 2022-11-12 19:13:16
# 1.3274369846781341e-05
# Near average price
# script continue running at 2022-11-12 19:13:23
# 1.0429862022304228e-05
# Near average price
# script continue running at 2022-11-12 19:13:30
# 5.278142296192396e-05
# Near average price
# script continue running at 2022-11-12 19:13:37
# 7.648565483100952e-05
# Near average price
# script continue running at 2022-11-12 19:13:44
# 0.00030562656289901633
# Near average price
# script continue running at 2022-11-12 19:13:51
# 0.00030562656289901633
# Near average price
# script continue running at 2022-11-12 19:13:58
# 0.0003095735991082539
# Near average price
# script continue running at 2022-11-12 19:14:05
# 0.0004359946707196926
# Near average price
# script continue running at 2022-11-12 19:14:12
# 0.0004755012555982111
# Near average price
# script continue running at 2022-11-12 19:14:19
# 0.0005071065235010258
# Near average price
# script continue running at 2022-11-12 19:14:26
# 0.0004834025725739148
# Near average price
# script continue running at 2022-11-12 19:14:33
# 0.0004913038895496184
# Near average price
# script continue running at 2022-11-12 19:14:40
# 0.0004913038895496184
# Near average price
# script continue running at 2022-11-12 19:14:47
# 0.0004913038895496184
# Near average price
# script continue running at 2022-11-12 19:14:54
# 0.0004675999386225074
# Near average price
# script continue running at 2022-11-12 19:15:01
# 0.0003162086066578589
# Near average price
# script continue running at 2022-11-12 19:15:09
# 0.0003241098711920303
# Near average price
# script continue running at 2022-11-12 19:15:16
# 0.00016576852992695535
# Near average price
# script continue running at 2022-11-12 19:15:22
# 0.0004107077304866278
# Near average price
# script continue running at 2022-11-12 19:15:29
# 0.00045021405315748476
# Near average price
# script continue running at 2022-11-12 19:15:36
# 0.0003633001432814198
# Near average price
# script continue running at 2022-11-12 19:15:43
# 0.00030009002700804867
# Near average price
# script continue running at 2022-11-12 19:15:50
# 0.00032379382061056285
# Near average price
# script continue running at 2022-11-12 19:15:57
# 0.00030009002700804867
# Near average price
# script continue running at 2022-11-12 19:16:04
# 0.0002898154062330318
# Near average price
# script continue running at 2022-11-12 19:16:11
# 0.0002898154062330318
# Near average price
# 0.0008079643281854756
# Near average price
# script continue running at 2022-11-12 19:23:11
# 0.0009502115690632104
# Near average price
# script continue running at 2022-11-12 19:23:18
# 0.0009502115690632104
# Near average price
# script continue running at 2022-11-12 19:23:25
# 0.0009186010710904203
# Near average price
# script continue running at 2022-11-12 19:23:32
# 0.0009106984465972229
# Near average price
# script continue running at 2022-11-12 19:23:39
# 0.0009186010710904203
# Near average price
# script continue running at 2022-11-12 19:23:46
# 0.0009581141935564078
# Near average price
# script continue running at 2022-11-12 19:23:53
# 0.0012663165487914697
# Near average price
# script continue running at 2022-11-12 19:24:00
# 0.00127426952365241
# Near average price
# script continue running at 2022-11-12 19:24:07
# 0.0012347548398378818
# Near average price
# script continue running at 2022-11-12 19:24:14
# 0.0013374930177556554
# Near average price
# script continue running at 2022-11-12 19:24:21
# 0.0012505607133636932
# Near average price
# script continue running at 2022-11-12 19:24:28
# 0.0012426577766007875
# Near average price
# script continue running at 2022-11-12 19:24:35
# 0.00027849949152539903
# Near average price
# script continue running at 2022-11-12 19:24:42
# 0.0001482590936718657
# Near average price
# script continue running at 2022-11-12 19:24:49
# 0.00044857069066264
# Near average price
# script continue running at 2022-11-12 19:24:56
# 0.00040905600684793203
# Near average price
# script continue running at 2022-11-12 19:25:03
# 0.00047227950095135693
# Near average price
# script continue running at 2022-11-12 19:25:10
# 0.0004931418509886298
# Near average price
# script continue running at 2022-11-12 19:25:17
# 0.0005247535081032786
# Near average price
# script continue running at 2022-11-12 19:25:24
# 0.0013466565930848674
# Near average price
# script continue running at 2022-11-12 19:25:31
# 0.0016785789927890398
# Near average price
# script continue running at 2022-11-12 19:25:38
# 0.0016785789927890398
# Near average price
# script continue running at 2022-11-12 19:25:45
# 0.0015205207072156157
# Near average price
# script continue running at 2022-11-12 19:25:52
# 0.0016943848213463641
# Near average price
# script continue running at 2022-11-12 19:25:59
# 0.0017101906499036885
# Near average price
# script continue running at 2022-11-12 19:26:06
# 0.0017736745725997355
# Near average price
# script continue running at 2022-11-12 19:26:13
# 0.001734161237797416
# Near average price
# script continue running at 2022-11-12 19:26:20
# 0.0013232225558548034
# Near average price
# script continue running at 2022-11-12 19:26:27
# 0.0015998158994701408
# Near average price
# script continue running at 2022-11-12 19:26:34
# 0.001465470561142686
# Near average price
# script continue running at 2022-11-12 19:26:41
# 0.0012679038871318076
# Near average price
# script continue running at 2022-11-12 19:26:48
# 0.0012600012201713798
# Near average price
# script continue running at 2022-11-12 19:26:55
# 0.0012600012201713798
# Near average price
# script continue running at 2022-11-12 19:27:02
# 0.0013503590684416271
# Near average price
# script continue running at 2022-11-12 19:27:09
# 0.001247628099985638
# Near average price
# script continue running at 2022-11-12 19:27:16
# 0.001247628099985638
# Near average price
# script continue running at 2022-11-12 19:27:23
# 0.000805094697406407
# Near average price
# script continue running at 2022-11-12 19:27:30
# 0.0005680232317389747
# Near average price
# script continue running at 2022-11-12 19:27:37
# 0.0004969017920386192
# Near average price
# script continue running at 2022-11-12 19:27:44
# 0.00045738988109407703
# Near average price
# script continue running at 2022-11-12 19:27:51
# 0.00044158511671626017
# Near average price
# script continue running at 2022-11-12 19:27:58
# 0.0005601208495500663
# Near average price
# script continue running at 2022-11-12 19:28:05
# 0.0005719721628620228
# Near average price
# script continue running at 2022-11-12 19:28:12
# 0.0005877768647924421
# Near average price
# script continue running at 2022-11-12 19:28:19
# 0.0006984097783053774
# Near average price
# script continue running at 2022-11-12 19:28:26
# 0.0005403627590011841
# Near average price
# script continue running at 2022-11-12 19:28:33
# 0.0005798745138272325
# Near average price
# script continue running at 2022-11-12 19:28:40
# 0.0006114839176880711
# Near average price
# script continue running at 2022-11-12 19:28:47
# 0.0005719721628620228
# Near average price
# script continue running at 2022-11-12 19:28:54
# 0.0005324604080357948
# Near average price
# script continue running at 2022-11-12 19:29:01
# 0.0006291863771425834
# Near average price
# script continue running at 2022-11-12 19:29:08
# 0.0006370887430951377
# Near average price
# script continue running at 2022-11-12 19:29:15
# 0.0006449911090476919
# Near average price
# script continue running at 2022-11-12 19:29:22
# 0.0006528934750002463
# Near average price
# script continue running at 2022-11-12 19:29:29
# 0.0006291863771425834
# Near average price
# script continue running at 2022-11-12 19:29:36
# 0.0006291863771425834
# Near average price
# script continue running at 2022-11-12 19:29:43
# 0.0006370887430951377
# Near average price
# script continue running at 2022-11-12 19:29:50
# 0.0006370887430951377
# Near average price
# script continue running at 2022-11-12 19:29:57
# 0.0006686982069053547
# Near average price
# script continue running at 2022-11-12 19:30:04
# 0.000668698206905175
# Near average price
# script continue running at 2022-11-12 19:30:11
# 0.0006607958409526207
# Near average price
# script continue running at 2022-11-12 19:30:18
# 0.000668698206905175
# Near average price
# script continue running at 2022-11-12 19:30:25
# 0.000668698206905175
# Near average price
# script continue running at 2022-11-12 19:30:32
# 0.0007556242323834517
# Near average price
# script continue running at 2022-11-12 19:30:39
# 0.0006607958409526207
# Near average price
# script continue running at 2022-11-12 19:30:46
# 0.0006607958409526207
# Near average price
# script continue running at 2022-11-12 19:30:53
# 0.00034470120285027005
# Near average price
# script continue running at 2022-11-12 19:31:00
# 0.00019013008343093848
# Near average price
# script continue running at 2022-11-12 19:31:07
# 0.0001980324144131104
# Near average price
# script continue running at 2022-11-12 19:31:14
# 0.00018222775244876652
# Near average price
# script continue running at 2022-11-12 19:31:21
# 0.00017432542146659458
# Near average price
# script continue running at 2022-11-12 19:31:28
# 9.4353831927611e-05
# Near average price
# script continue running at 2022-11-12 19:31:35
# 0.0001970841346958463
# Near average price
# script continue running at 2022-11-12 19:31:42
# 0.00027610744451774547
# Near average price
# script continue running at 2022-11-12 19:31:49
# 0.00020498646567801827
# Near average price
# script continue running at 2022-11-12 19:31:56
# 4.6939846034399634e-05
# Near average price
# script continue running at 2022-11-12 19:32:03
# 5.484217701657158e-05
# Near average price
# script continue running at 2022-11-12 19:32:10
# 5.705425258873285e-05
# Near average price
# script continue running at 2022-11-12 19:32:17
# 0.0003617650531163072
# Near average price
# script continue running at 2022-11-12 19:32:24
# 0.00060673483569847
# Near average price
# script continue running at 2022-11-12 19:32:31
# 0.00060673483569847
# Near average price
# script continue running at 2022-11-12 19:32:38
# 0.0006225393378005334
# Near average price
# script continue running at 2022-11-12 19:32:45
# 0.0005672235804433114
# Near average price
# script continue running at 2022-11-12 19:32:52
# 0.0010097496393014465
# Near average price
# script continue running at 2022-11-12 19:32:59
# 0.0010097496393014465
# Near average price
# script continue running at 2022-11-12 19:33:06
# 0.0009752622232151332
# Near average price
# script continue running at 2022-11-12 19:33:13
# 0.0012360275235400525
# Near average price
# script continue running at 2022-11-12 19:33:20
# 0.0011095958627765424
# Near average price
# script continue running at 2022-11-12 19:33:27
# 0.0007065949440924946
# Near average price
# script continue running at 2022-11-12 19:33:34
# 0.0006986929652947752
# Near average price
# script continue running at 2022-11-12 19:33:41
# 0.0009357523292265363
# Near average price
# script continue running at 2022-11-12 19:33:48
# 0.0008251246260582853
# Near average price
# script continue running at 2022-11-12 19:33:55
# 0.0008567325412491628
# Near average price
# script continue running at 2022-11-12 19:34:02
# 0.0008277873582107144
# Near average price
# script continue running at 2022-11-12 19:34:09
# 0.0008277873582107144
# Near average price
# script continue running at 2022-11-12 19:34:16
# 0.0006065383506705698
# Near average price
# script continue running at 2022-11-12 19:34:23
# 0.0007250646047100164
# Near average price
# script continue running at 2022-11-12 19:34:30
# 0.0005196190977084408
# Near average price
# script continue running at 2022-11-12 19:34:37
# 0.0009384118619808765
# Near average price
# script continue running at 2022-11-12 19:34:44
# 0.0009858223635965833
# Near average price
# script continue running at 2022-11-12 19:34:51
# 0.0010095276144044367
# Near average price
# script continue running at 2022-11-12 19:34:58
# 0.0007803768565950077
# Near average price
# script continue running at 2022-11-12 19:35:05
# 0.0007874940321602645
# Near average price
# script continue running at 2022-11-12 19:35:12
# 0.0008191012580145672
# Near average price
# script continue running at 2022-11-12 19:35:19
# 0.0008111994515509916
# Near average price
# script continue running at 2022-11-12 19:35:26
# 0.0013564240975382522
# Near average price
# script continue running at 2022-11-12 19:35:33
# 0.001498656613882794
# Near average price
# script continue running at 2022-11-12 19:35:40
# 0.001546067452664248
# Near average price
# script continue running at 2022-11-12 19:35:47
# 0.0014670493880284913
# Near average price
# script continue running at 2022-11-12 19:35:54
# 0.0015855764849821265
# Near average price
# script continue running at 2022-11-12 19:36:01
# 0.001561054981120946
# Near average price
# script continue running at 2022-11-12 19:36:08
# 0.0015373499550865278
# Near average price
# script continue running at 2022-11-12 19:36:15
# 0.0015373499550865278
# Near average price
# script continue running at 2022-11-12 19:36:22
# 0.0015373499550865278
# Near average price
# script continue running at 2022-11-12 19:36:29
# 0.0015373499550865278
# Near average price
# script continue running at 2022-11-12 19:36:36
# 0.0015373499550865278
# Near average price
# script continue running at 2022-11-12 19:36:43
# 0.0011422661878458626
# Near average price
# script continue running at 2022-11-12 19:36:50
# 0.0010869544604322197
# Near average price
# script continue running at 2022-11-12 19:36:57
# 0.0012449879673285217
# Near average price
# script continue running at 2022-11-12 19:37:04
# 0.001139119919237081
# Near average price
# script continue running at 2022-11-12 19:37:11
# 0.0014472891537698875
# Near average price
# script continue running at 2022-11-12 19:37:18
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-12 19:42:05
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-12 19:42:19
# 0.0018717683786191525
# Near average price
# script continue running at 2022-11-12 19:42:26
# 0.0017453402544300059
# Near average price
# script continue running at 2022-11-12 19:42:33
# 0.001618912130240859
# Near average price
# script continue running at 2022-11-12 19:42:40
# 0.0014450734594808497
# Near average price
# script continue running at 2022-11-12 19:42:47
# 0.001381859397386366
# Near average price
# script continue running at 2022-11-12 19:42:54
# 0.001413466428433608
# Near average price
# script continue running at 2022-11-12 19:43:01
# 0.0007655222919646126
# Near average price
# script continue running at 2022-11-12 19:43:08
# 0.0009422082757554411
# Near average price
# script continue running at 2022-11-12 19:43:15
# 0.0007762708907263149
# Near average price
# script continue running at 2022-11-12 19:43:22
# 0.0003732800985127997
# Near average price
# script continue running at 2022-11-12 19:43:29
# 0.0003732800985127997
# Near average price
# script continue running at 2022-11-12 19:43:36
# 0.00022314627396262076
# Near average price
# script continue running at 2022-11-12 19:43:43
# 0.0001599320320468316
# Near average price
# script continue running at 2022-11-12 19:43:50
# 0.00047600324162613676
# Near average price
# script continue running at 2022-11-12 19:43:57
# 0.00038118187875227334
# Near average price
# script continue running at 2022-11-12 19:44:04
# 0.00021366886509565313
# Near average price
# script continue running at 2022-11-12 19:44:11
# 0.00015835517960489405
# Near average price
# script continue running at 2022-11-12 19:44:18
# 0.0004033157867784353
# Near average price
# script continue running at 2022-11-12 19:44:25
# 0.0007668057200037829
# Near average price
# script continue running at 2022-11-12 19:44:32
# 0.0005218451128302416
# Near average price
# script continue running at 2022-11-12 19:44:39
# 0.00038751187663821845
# Near average price
# script continue running at 2022-11-12 19:44:46
# 0.0002847864607266291
# Near average price
# script continue running at 2022-11-12 19:44:53
# 0.0002847864607266291
# Near average price
# script continue running at 2022-11-12 19:45:00
# 0.00040632617134038056
# Near average price
# script continue running at 2022-11-12 19:45:07
# 0.0009673755327793127
# Near average price
# script continue running at 2022-11-12 19:45:14
# 0.0009673755327793127
# Near average price
# script continue running at 2022-11-12 19:45:21
# 0.0005406619339384854
# Near average price
# script continue running at 2022-11-12 19:45:28
# 0.0003984240676581497
# Near average price
# script continue running at 2022-11-12 19:45:35
# 0.000256186201377814
# Near average price
# script continue running at 2022-11-12 19:45:42
# 7.44378166863239e-05
# Near average price
# script continue running at 2022-11-12 19:45:49
# 5.8633609321862124e-05
# Near average price
# script continue running at 2022-11-12 19:45:56
# 2.8289531182677653e-05
# Near average price
# script continue running at 2022-11-12 19:46:03
# 0.00015425279377738026
# Near average price
# script continue running at 2022-11-12 19:46:10
# 0.00015425279377738026
# Near average price
# ...
# 0.0010241213945884951
# Near average price
# script continue running at 2022-11-12 20:01:48
# 0.0011743090026246287
# Near average price
# script continue running at 2022-11-12 20:01:55
# 0.0011189767259797373
# Near average price
# script continue running at 2022-11-12 20:02:02
# 0.0008853125074106334
# Near average price
# script continue running at 2022-11-12 20:02:09
# 0.0008459478528718779
# Near average price
# script continue running at 2022-11-12 20:02:16
# 0.0011147034779665694
# Near average price
# script continue running at 2022-11-12 20:02:23
# 0.00100403939704512
# Near average price
# script continue running at 2022-11-12 20:02:30
# 0.00100403939704512
# Near average price
# script continue running at 2022-11-12 20:02:37
# 0.00100403939704512
# Near average price
# script continue running at 2022-11-12 20:02:44
# 0.0007748066579937393
# Near average price
# script continue running at 2022-11-12 20:02:51
# 0.0007036654631157803
# Near average price
# script continue running at 2022-11-12 20:02:58
# 0.0006483334226551455
# Near average price
# script continue running at 2022-11-12 20:03:05
# 0.0006329938395348254
# Near average price
# script continue running at 2022-11-12 20:03:12
# 0.0006962299873404104
# Near average price
# script continue running at 2022-11-12 20:03:19
# 0.0007041345058161085
# Near average price
# script continue running at 2022-11-12 20:03:26
# 0.000735752579718901
# Near average price
# script continue running at 2022-11-12 20:03:33
# 0.000735752579718901
# Near average price
# script continue running at 2022-11-12 20:03:40
# 0.0006408983580105236
# Near average price
# script continue running at 2022-11-12 20:03:47
# 0.0006488028764862217
# Near average price
# script continue running at 2022-11-12 20:03:54
# 0.0007752751720973915
# Near average price
# script continue running at 2022-11-12 20:04:01
# 0.0006468943380623161
# Near average price
# script continue running at 2022-11-12 20:04:08
# 0.0007496512588198794
# Near average price
# script continue running at 2022-11-12 20:04:15
# 0.0005125199032253227
# Near average price
# script continue running at 2022-11-12 20:04:22
# 0.0005125199032253227
# Near average price
# script continue running at 2022-11-12 20:04:29
# 0.0006547987165821285
# Near average price
# script continue running at 2022-11-12 20:04:36
# 0.0005362330387847603
# Near average price
# script continue running at 2022-11-12 20:04:43
# 0.0005283286602649478
# Near average price
# script continue running at 2022-11-12 20:04:50
# 0.0005204242817451353
# Near average price
# script continue running at 2022-11-12 20:04:57
# 0.0005283286602649478
# Near average price
# script continue running at 2022-11-12 20:05:04
# 0.000777149158889657
# Near average price
# script continue running at 2022-11-12 20:05:11
# 0.0007218191740216677
# Near average price
# script continue running at 2022-11-12 20:05:18
# 0.0007218191740216677
# Near average price
# script continue running at 2022-11-12 20:05:25
# 0.00042936068257640186
# Near average price
# script continue running at 2022-11-12 20:05:32
# 0.00042145639902383195
# Near average price
# script continue running at 2022-11-12 20:05:39
# 0.00046888210033925134
# Near average price
# script continue running at 2022-11-12 20:05:46
# 0.0004609778167866814
# Near average price
# script continue running at 2022-11-12 20:05:53
# 0.0005004992345495309
# Near average price
# script continue running at 2022-11-12 20:06:00
# 0.0004609778167866814
# Near average price
# script continue running at 2022-11-12 20:06:07
# 0.0004260428366711982
# Near average price
# script continue running at 2022-11-12 20:06:14
# 0.0003390953189832059
# Near average price
# script continue running at 2022-11-12 20:06:21
# 0.0003549039585628082
# Near average price
# script continue running at 2022-11-12 20:09:58
# 0.00022226458844561936
# Near average price
# script continue running at 2022-11-12 20:10:05
# 0.0001884299579608423
# Near average price
# script continue running at 2022-11-12 20:10:12
# 0.0001884299579608423
# Near average price
# script continue running at 2022-11-12 20:10:19
# 3.288039534846896e-05
# Near average price
# script continue running at 2022-11-12 20:10:26
# 4.868827772769264e-05
# Near average price
# script continue running at 2022-11-12 20:10:33
# 5.6592218917484194e-05
# Near average price
# script continue running at 2022-11-12 20:10:40
# 6.449616010709604e-05
# Near average price
# script continue running at 2022-11-12 20:10:47
# 5.6592218917484194e-05
# Near average price
# script continue running at 2022-11-12 20:10:54
# 6.449616010709604e-05
# Near average price
# script continue running at 2022-11-12 20:11:01
# 0.00012914919450853185
# Near average price
# script continue running at 2022-11-12 20:11:08
# 0.00012914919450853185
# Near average price
# script continue running at 2022-11-12 20:11:15
# 0.00012124532703553035
# Near average price
# script continue running at 2022-11-12 20:11:22
# 0.00012914919450853185
# Near average price
# script continue running at 2022-11-12 20:11:29
# 0.0009195359418094009
# Near average price
# script continue running at 2022-11-12 20:11:36
# 0.000951151411701407
# Near average price
# script continue running at 2022-11-12 20:11:43
# 0.0006745160501461747
# Near average price
# script continue running at 2022-11-12 20:11:50
# 0.0006429005802539889
# Near average price
# script continue running at 2022-11-12 20:13:00
# 0.00043155027718774216
# Near average price
# script continue running at 2022-11-12 20:13:07
# 1.2646161968581919e-05
# Near average price
# script continue running at 2022-11-12 20:13:14
# 0.000477392614325469
# Near average price
# script continue running at 2022-11-12 20:13:21
# 0.0009595275393891562
# Near average price
# script continue running at 2022-11-12 20:13:28
# 0.0008093543660086517
# Near average price
# script continue running at 2022-11-12 20:13:35
# 0.0007698351098559346
# Near average price
# script continue running at 2022-11-12 20:13:42
# 0.0005485272754005394
# Near average price
# script continue running at 2022-11-12 20:13:49
# 0.0005485272754005394
# Near average price
# script continue running at 2022-11-12 20:13:56
# 0.0005485272754005394
# Near average price
# script continue running at 2022-11-12 20:14:03
# 0.0008480557551214054
# Near average price
# script continue running at 2022-11-12 20:14:10
# 0.0009824168719626805
# Near average price
# script continue running at 2022-11-12 20:14:17
# 0.0011009707985873561
# Near average price
# script continue running at 2022-11-12 20:14:24
# 0.0010930672034790564
# Near average price
# script continue running at 2022-11-12 20:14:31
# 0.0010930672034790564
# Near average price
# script continue running at 2022-11-12 20:14:38
# 0.0011009707985873561
# Near average price
# script continue running at 2022-11-12 20:14:45
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-12 20:18:22
# 1.897014257670022e-05
# Near average price
# script continue running at 2022-11-12 20:18:29
# 2.6874368650205496e-05
# Near average price
# script continue running at 2022-11-12 20:18:36
# 2.0550987791005887e-05
# Near average price
# script continue running at 2022-11-12 20:18:43
# 0.00017863550926111143
# Near average price
# script continue running at 2022-11-12 20:18:50
# 0.00011540170067306921
# Near average price
# script continue running at 2022-11-12 20:18:57
# 9.010817723824772e-05
# Near average price
# script continue running at 2022-11-12 20:19:04
# 5.374955300832041e-06
# Near average price
# script continue running at 2022-11-12 20:19:11
# 0.00021594673356086953
# Near average price
# script continue running at 2022-11-12 20:19:18
# 2.5293907301099016e-06
# Near average price
# script continue running at 2022-11-12 20:19:25
# 1.3279301331594259e-05
# Near average price
# script continue running at 2022-11-12 20:19:32
# 2.1183647362356477e-05
# Near average price
# script continue running at 2022-11-12 20:19:39
# 1.3279301331594259e-05
# Near average price
# script continue running at 2022-11-12 20:19:46
# 5.280103148540535e-05
# Near average price
# script continue running at 2022-11-12 20:19:53
# 0.0003215487965315005
# Near average price
# script continue running at 2022-11-12 20:20:00
# 0.0003294531425622627
# Near average price
# script continue running at 2022-11-12 20:20:07
# 0.00013200568810114085
# Near average price
# script continue running at 2022-11-12 20:20:14
# 8.14166818831227e-05
# Near average price
# script continue running at 2022-11-12 20:20:21
# 0.0001525574718778173
# Near average price
# script continue running at 2022-11-12 20:20:28
# 7.351214966148997e-05
# Near average price
# script continue running at 2022-11-12 20:20:35
# 5.296036588481351e-05
# Near average price
# script continue running at 2022-11-12 20:20:42
# 1.8180424109881097e-05
# Near average price
# script continue running at 2022-11-12 20:20:49
# 1.8180424109881097e-05
# Near average price
# script continue running at 2022-11-12 20:20:56
# 0.00013200568810114085
# Near average price
# script continue running at 2022-11-12 20:21:03
# 1.7864446163265472e-05
# Near average price
# script continue running at 2022-11-12 20:21:10
# 9.959823967061916e-06
# Near average price
# script continue running at 2022-11-12 20:21:17
# 0.00012852915691011527
# Near average price
# script continue running at 2022-11-12 20:21:24
# 0.00012062453471391173
# Near average price
# script continue running at 2022-11-12 20:21:31
# 0.00012852915691011527
# Near average price
# script continue running at 2022-11-12 20:21:38
# 0.0003419539562077911
# Near average price
# script continue running at 2022-11-12 20:21:45
# 0.0001917661344799235
# Near average price
# script continue running at 2022-11-12 20:21:52
# 0.00020757537887233058
# Near average price
# script continue running at 2022-11-12 20:21:59
# 0.00019967075667612705
# Near average price
# script continue running at 2022-11-12 20:22:06
# 0.000215797823524738
# Near average price
# script continue running at 2022-11-12 20:22:13
# 0.0004450336067561908
# Near average price
# script continue running at 2022-11-12 20:22:20
# 0.0005082710641993006
# Near average price
# script continue running at 2022-11-12 20:22:27
# 0.0006979834365288097
# Near average price
# script continue running at 2022-11-12 20:22:34
# 0.00043712892457580205
# Near average price
# script continue running at 2022-11-12 20:22:41
# 0.0005794132038229789
# Near average price
# script continue running at 2022-11-12 20:22:48
# 0.0007058881187091985
# Near average price
# script continue running at 2022-11-12 20:22:55
# 0.0006347459790856999
# Near average price
# script continue running at 2022-11-12 20:23:02
# 0.0006042571194672578
# Near average price
# script continue running at 2022-11-12 20:23:09
# 0.0005963521336029607
# Near average price
# script continue running at 2022-11-12 20:23:16
# 0.0004619673739097304
# Near average price
# script continue running at 2022-11-12 20:23:23
# 0.0006042571194672578
# Near average price
# script continue running at 2022-11-12 20:23:30
# 0.0002090078262520438
# Near average price
# script continue running at 2022-11-12 20:23:37
# 0.0002090078262520438
# Near average price
# script continue running at 2022-11-12 20:23:44
# 0.00024853275557352924
# Near average price
# script continue running at 2022-11-12 20:23:51
# 0.0002801526990307176
# Near average price
# script continue running at 2022-11-12 20:23:58
# 0.0004619673739097304
# Near average price
# script continue running at 2022-11-12 20:24:05
# 0.0007451485893955038
# Near average price
# script continue running at 2022-11-12 20:24:12
# 0.0011246004490495561
# Near average price
# script continue running at 2022-11-12 20:24:19
# 0.0011325056961256747
# Near average price
# script continue running at 2022-11-12 20:24:26
# 0.001187842425658505
# Near average price
# script continue running at 2022-11-12 20:24:33
# 0.0007056223540149107
# Near average price
# script continue running at 2022-11-12 20:24:40
# 0.0003894124709698072
# Near average price
# script continue running at 2022-11-12 20:24:47
# 0.0003182652472847398
# Near average price
# script continue running at 2022-11-12 20:24:54
# 0.00041312821219816303
# Near average price
# script continue running at 2022-11-12 20:25:01
# 0.00038104513882829694
# Near average price
# script continue running at 2022-11-12 20:25:08
# 0.0006103046621898137
# Near average price
# script continue running at 2022-11-12 20:25:15
# 0.0008474696863570735
# Near average price
# script continue running at 2022-11-12 20:25:22
# 0.0008553751871626369
# Near average price
# script continue running at 2022-11-12 20:25:29
# 0.0009186191936071435
# Near average price
# script continue running at 2022-11-12 20:25:36
# 0.001116256713746407
# Near average price
# script continue running at 2022-11-12 20:25:43
# 0.001021390704079467
# Near average price
# script continue running at 2022-11-12 20:25:50
# 0.0010292962048850305
# Near average price
# script continue running at 2022-11-12 20:25:57
# 0.0010925402113297169
# Near average price
# script continue running at 2022-11-12 20:26:04
# 0.0005450408163940992
# Near average price
# script continue running at 2022-11-12 20:26:11
# 0.0002920482703451579
# Near average price
# script continue running at 2022-11-12 20:26:18
# 0.00028414225328113405
# Near average price
# script continue running at 2022-11-12 20:26:25
# 0.00024461216796101506
# Near average price
# script continue running at 2022-11-12 20:26:32
# 0.00024461216796101506
# Near average price
# script continue running at 2022-11-12 20:26:39
# 0.00032367233860125305
# Near average price
# script continue running at 2022-11-12 20:26:46
# 0.0004976047140099564
# Near average price
# script continue running at 2022-11-12 20:26:53
# 0.0006715370894186598
# Near average price
# script continue running at 2022-11-12 20:27:00
# 0.0005292287822660516
# Near average price
# script continue running at 2022-11-12 20:27:07
# 0.00047628369683416934
# Near average price
# script continue running at 2022-11-12 20:27:14
# 0.00046837726096375225
# Near average price
# script continue running at 2022-11-12 20:27:21
# 0.0004051257740004156
# Near average price
# script continue running at 2022-11-12 20:27:28
# 0.0004051257740004156
# Near average price
# script continue running at 2022-11-12 20:27:35
# 0.0004051257740004156
# Near average price
# script continue running at 2022-11-12 20:27:42
# 0.00039721933812999853
# Near average price
# script continue running at 2022-11-12 20:27:49
# 0.00046047082509333517
# Near average price
# script continue running at 2022-11-12 20:27:56
# 0.00046047082509333517
# Near average price
# script continue running at 2022-11-12 20:28:03
# 0.000145485137586219
# Near average price
# script continue running at 2022-11-12 20:28:10
# 0.000145485137586219
# Near average price
# script continue running at 2022-11-12 20:28:17
# 0.0001533919385419859
# Near average price
# script continue running at 2022-11-12 20:28:24
# 4.2696725161069396e-05
# Near average price
# script continue running at 2022-11-12 20:28:31
# 9.962569204273496e-05
# Near average price
# script continue running at 2022-11-12 20:28:38
# 9.962569204273496e-05
# Near average price
# script continue running at 2022-11-12 20:28:45
# 9.962569204273496e-05
# Near average price
# script continue running at 2022-11-12 20:28:52
# 9.171889108696805e-05
# Near average price
# script continue running at 2022-11-12 20:28:59
# 9.962569204273496e-05
# Near average price
# script continue running at 2022-11-12 20:29:06
# 0.00015102766020184217
# Near average price
# script continue running at 2022-11-12 20:29:13
# 0.00015102766020184217
# Near average price
# script continue running at 2022-11-12 20:29:20
# 0.00015102766020184217
# Near average price
# script continue running at 2022-11-12 20:29:27
# 8.777000147854996e-05
# Near average price
# script continue running at 2022-11-12 20:29:34
# 0.00033289342903148705
# Near average price
# script continue running at 2022-11-12 20:29:41
# 0.0008626763208395986
# Near average price
# script continue running at 2022-11-12 20:29:48
# 0.0008705835281800102
# Near average price
# script continue running at 2022-11-12 20:29:55
# 0.0009417483942437139
# Near average price
# script continue running at 2022-11-12 20:30:02
# 0.001086795279209223
# Near average price
# script continue running at 2022-11-12 20:30:09
# 0.0010551656145058384
# Near average price
# script continue running at 2022-11-12 20:30:16
# 0.0007467763836474788
# Near average price
# script continue running at 2022-11-12 20:30:23
# 0.000651887389537325
# Near average price
# script continue running at 2022-11-12 20:30:30
# 0.000651887389537325
# Near average price
# script continue running at 2022-11-12 20:30:37
# 0.0003118684939755808
# Near average price
# script continue running at 2022-11-12 20:30:44
# 0.00028814624544804235
# Near average price
# script continue running at 2022-11-12 20:30:51
# 0.00013885422804800945
# Near average price
