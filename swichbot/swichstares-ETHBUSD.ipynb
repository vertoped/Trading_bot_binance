# %%
import requests
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import copy
import time
import random
import threading
import coinconfig

from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
from binance.helpers import round_step_size
from futures_sign import send_signed_request, send_public_request
from cred import KEY, SECRET

# %%
#0:BTCBUSD, 1:BTCUSDT, 2:DOGEUSDT, 3:DOGEBUSD, 4:ETHBUSD, 5:ETHUSDT, 6:EOSUSDT, 7:LTCUSDT, 8:BNBBUSD

# %%
client = Client(KEY, SECRET, testnet=False)
config=coinconfig.tradeconfig
coin=coinconfig.coinlist[4]

# %%
symbol=coin["symbol"]
asset=coin["asset"]
recvWindow=config["recvWindow"]
dualSidePosition=config["dualSidePosition"]
marginType=config["marginType"]

leverage=coin["leverage"]
roundity=coin["roundity"]
profit_percent=coin["profit_percent"]
diference=coin["diference"]
stop_percent=profit_percent-diference
balance_part=coin["balance_part"]
compensation=coin["compensation"]
ingebit=coin["ingebit"]

# %%
client.futures_change_leverage(symbol=symbol, leverage=leverage, recvWindow=recvWindow)
# Out:
# {'symbol': 'ETHBUSD', 'leverage': 50, 'maxNotionalValue': '50000'}

# %%
# Margin type
def margin_type_to_isolated():
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    body=positions[positions['symbol']==symbol]['isolated'].astype(bool).tolist()[0]

    if body==True:
        client.futures_change_margin_type(symbol=symbol, marginType=marginType, recvWindow=recvWindow)
        print(f'Changed to {marginType}')
    else:
        print(f'Already {marginType}')

# %%
# Hedge mode turn on

def hedge_mode_turn_on():
    status=client.futures_get_position_mode() 
    if status['dualSidePosition']==False:
        client.futures_change_position_mode(dualSidePosition=dualSidePosition, recvWindow=recvWindow)
        client.futures_get_position_mode()
        print('Dual turned on')
    else:
        print('Already Dual')
    return(status['dualSidePosition'])

# %%
def get_assetbalance(symbol):
    status = client.futures_account()
    balance = pd.DataFrame(status['assets'])
    assetbalance = float(balance.loc[balance['asset'] == asset, 'availableBalance'])
    return(assetbalance)

# %%
# Find all opened positions

def get_opened_positions(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    open_positions=positions[positions['symbol']==symbol]
    position_long=float(open_positions[open_positions['positionSide']=='LONG']['entryPrice'])
    position_short=float(open_positions[open_positions['positionSide']=='SHORT']['entryPrice'])
    return(position_long,position_short)

# %%
def get_quant(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    open_positions=positions[positions['symbol']==symbol]
    quant=float(open_positions[open_positions['positionSide']=='LONG']['positionAmt'])
    if quant==0:
        quant=abs(float(open_positions[open_positions['positionSide']=='SHORT']['positionAmt']))
    return(quant)

# %%
# Close all orders 

def check_and_close_orders(symbol):
    global isStop 
    a=client.futures_get_open_orders(symbol=symbol)
    if len(a)>0:
        isStop = False
        client.futures_cancel_all_open_orders(symbol=symbol)

# %%
def get_symbol_price(symbol):
    prices = client.get_all_tickers()
    df=pd.DataFrame(prices)
    return float(df[ df['symbol']==symbol]['price'])

# %%
#получить tick size

def get_tick_size(symbol):
    data = client.futures_exchange_info()
    tick_size = 0.0
    the_symbol = symbol

    found = False
    info = data['symbols']
    for s in range(len(info)):
        if info[s]['symbol'] == the_symbol:
            filters = info[s]['filters']
            for f in range(len(filters)):
                if filters[f]['filterType'] == 'PRICE_FILTER':
                    tick_size = float(filters[f]['tickSize'])
                    found = True
                    break
            break
    return(tick_size)

# %%
#Trade config

# maxposition=0.016 #1 = 100% = 1 BTC,
asset_balance=get_assetbalance(symbol)
symbol_price=get_symbol_price(symbol)
maxposition=round(asset_balance*balance_part*leverage/symbol_price,3)
quantity=str(round(maxposition/2,roundity))
tick_size=get_tick_size(symbol)
symbolround=abs(str(tick_size).find('.') - len(str(tick_size))) - 1
roundity
# Out:
# 3

# %%
#Stop loss LONG 
def open_sl_long(symbol,quant,tick_size,stop_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[0]
        stop_price_trigger=str(round(float(entry_price)*(1-stop_percent), symbolround))
        stop_price=str(round(float(stop_price_trigger)*0.9999, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "positionSide": "LONG",
                    "type": "STOP",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": stop_price_trigger,
                    "price": stop_price
                }
            ]
        }

        open_position_sl_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        long_sl_opened=float(open_position_sl_long_response[0]['price'])
        print('LONG sl order opened price:'+str(long_sl_opened))
        return(long_sl_opened)
    
    except :
        print('\n\nSL long not open...')

# %%
def open_sl_long_steps(symbol,quantity,tick_size,stop_percent):
    stop_step=stop_percent/4  
    quant=str(get_quant(symbol))
    # x = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*3/2))
    # x.start()
    y = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit),roundity)),tick_size,stop_step*2))
    y.start()
    z = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*5/2))
    z.start()
    w = threading.Thread(target=open_sl_long, args=(symbol,quant,tick_size,stop_step*3))
    w.start()

# %%
#Take Profit LONG 

def open_tp_long(symbol,quant,tick_size,profit_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[0]
        take_price_trigger=str(round(float(entry_price)*(1+profit_percent), symbolround))
        take_price=str(round(float(take_price_trigger)*0.9999, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "positionSide": "LONG",
                    "type": "TAKE_PROFIT",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": take_price_trigger,
                    "price": take_price
                }
            ]
        }
        open_position_tp_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        long_tp_opened=float(open_position_tp_long_response[0]['price'])
        print('LONG tp order opened price:'+str(long_tp_opened))
        return(long_tp_opened)
        
    except :
        print('\n\nTP long not open...')

# %%
def open_tp_long_steps(symbol,quantity,tick_size,profit_percent):
    quant=str(round(float(quantity)/(ingebit),roundity))
    profit_step=profit_percent/4
    
    # x = threading.Thread(target=open_tp_long, args=(symbol,quantity,tick_size,profit_percent))
    # x.start()
    # y = threading.Thread(target=open_tp_long, args=(symbol,quant,tick_size,profit_step))
    # y.start()
    z = threading.Thread(target=open_tp_long, args=(symbol,quant,tick_size,profit_step*2))
    z.start()
    w = threading.Thread(target=open_tp_long, args=(symbol,quantity,tick_size,profit_step*3))
    w.start()

# %%
#Открыть sl&tp LONG если есть позиция

def long_tp_sl_opening(symbol,quantity,profit_percent,stop_percent):
    position=get_opened_positions(symbol)
    if position[0]>0:
        x = threading.Thread(target=open_tp_long_steps, args=(symbol,quantity,tick_size,profit_percent))
        x.start()
        y = threading.Thread(target=open_sl_long_steps, args=(symbol,quantity,tick_size,stop_percent))
        y.start()

# %%
#Открыть позицию LONG 

def open_position_long(symbol,quantity,tick_size,profit_percent,stop_percent,close_price):
    tick=str(tick_size)
    params = {
        "batchOrders": [
            {
                "symbol":symbol,
                "side": "BUY",
                "positionSide": "LONG",
                "type": "LIMIT",
                "quantity": quantity,
                "timeInForce":"GTC",
                "tickSize": tick,
                "price": close_price        
            }
        ]
    }
    open_position_long_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
    long_opened=float(open_position_long_response[0]['price'])
    if long_opened>0:
        print('LONG order opened price:'+str(long_opened))
        long_tp_sl=long_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)
    else:
        print('LONG not open')

# %%
def open_position_long_steps(symbol):
    quant=str(round(float(quantity)/ingebit,roundity))
    sprice=get_symbol_price(symbol)
    close_price=str(round(sprice*(1+0.001),symbolround))
    open_position_long(symbol,quantity,tick_size,profit_percent,stop_percent,close_price)

# %%
#Stop loss SHORT 

def open_sl_short(symbol,quant,tick_size,stop_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[1]
        stop_price_trigger=str(round(float(entry_price)*(1+stop_percent), symbolround))
        stop_price=str(round(float(stop_price_trigger)*1.0001, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "positionSide": "SHORT",
                    "type": "STOP",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": stop_price_trigger,
                    "price": stop_price
                }
            ]
        }
        
        open_position_sl_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        short_sl_opened=float(open_position_sl_short_response[0]['price'])
        print('SHORT sl order opened price:'+str(short_sl_opened))
        return(short_sl_opened)
    
    except :
        print('\n\nSL short not open...')

# %%
def open_sl_short_steps(symbol,quantity,tick_size,stop_percent):
    stop_step=stop_percent/4 
    quant=str(get_quant(symbol))
    # x = threading.Thread(target=open_sl_long, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*3/2))
    # x.start()
    y = threading.Thread(target=open_sl_short, args=(symbol,str(round(float(quant)/(ingebit),roundity)),tick_size,stop_step*2))
    y.start()
    z = threading.Thread(target=open_sl_short, args=(symbol,str(round(float(quant)/(ingebit*2),roundity)),tick_size,stop_step*5/2))
    z.start()
    w = threading.Thread(target=open_sl_short, args=(symbol,quant,tick_size,stop_step*3))
    w.start()

# %%
#Take Profit SHORT

def open_tp_short(symbol,quant,tick_size,profit_percent):
    try:
        positions=get_opened_positions(symbol)
        entry_price=positions[1]
        take_price_trigger=str(round(float(entry_price)*(1-profit_percent), symbolround))
        take_price=str(round(float(take_price_trigger)*1.0001, symbolround))
        tick=str(tick_size)
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "positionSide": "SHORT",
                    "type": "TAKE_PROFIT",
                    "quantity": quant,
                    "timeInForce":"GTE_GTC",
                    "tickSize": tick,
                    "stopPrice": take_price_trigger,
                    "price": take_price
                }
            ]
        }

        open_position_tp_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
        short_tp_opened=float(open_position_tp_short_response[0]['price'])
        print('SHORT tp order opened price:'+str(short_tp_opened))
        return(short_tp_opened)
    
    except :
        print('\n\nTp short not open...')

# %%
def open_tp_short_steps(symbol,quantity,tick_size,profit_percent):
    quant=str(round(float(quantity)/(ingebit),roundity))
    profit_step=profit_percent/4
    
    # x = threading.Thread(target=open_tp_short, args=(symbol,quantity,tick_size,profit_percent))
    # x.start()
    # y = threading.Thread(target=open_tp_short, args=(symbol,quant,tick_size,profit_step))
    # y.start()
    z = threading.Thread(target=open_tp_short, args=(symbol,quant,tick_size,profit_step*2))
    z.start()
    w = threading.Thread(target=open_tp_short, args=(symbol,quantity,tick_size,profit_step*3))
    w.start()

# %%
#Открыть sl&tp SHORT если есть позиция
       
def short_tp_sl_opening(symbol,quantity,profit_percent,stop_percent):
    position=get_opened_positions(symbol)
    if position[1]>0:
        x = threading.Thread(target=open_tp_short_steps, args=(symbol,quantity,tick_size,profit_percent))
        x.start()
        y = threading.Thread(target=open_sl_short_steps, args=(symbol,quantity,tick_size,stop_percent))
        y.start()

# %%
#Открыть позицию SHORT

def open_position_short(symbol,quantity,tick_size,profit_percent,stop_percent,close_price):
    tick=str(tick_size)
    params = {
        "batchOrders": [
            {
                "symbol":symbol,
                "side": "SELL",
                "positionSide": "SHORT",
                "type": "LIMIT",
                "quantity": quantity,
                "timeInForce":"GTC",
                "tickSize": tick,
                "price": close_price        
            }
        ]
    }
    open_position_short_response=send_signed_request('POST', '/fapi/v1/batchOrders', params)
    short_opened=float(open_position_short_response[0]['price'])    
    if short_opened>0:
        print('SHORT order opened price:'+str(short_opened))
        short_tp_sl=short_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)
    else:
        print('SHORT not open')

# %%
def open_position_short_steps(symbol):
    quant=str(round(float(quantity)/ingebit,roundity))
    sprice=get_symbol_price(symbol)
    close_price=str(round(sprice*(1-0.001),symbolround))
    open_position_short(symbol,quantity,tick_size,profit_percent,stop_percent,close_price)

# %%
def get_profit(symbol):
    trades = client.futures_account_trades(symbol=symbol)
    dataset=pd.DataFrame(trades).iloc[-10:]
    bnbcom=dataset[dataset['commissionAsset']=='BNB']['commission'].astype(float).sum()
    busdcom=dataset[dataset['commissionAsset']==asset]['commission'].astype(float).sum()
    com=(bnbcom*270+busdcom)*-1
    real=dataset['realizedPnl'].astype(float).sum()
    profit=float(com+real)
    dataseto=pd.DataFrame(trades)['realizedPnl'].astype(float)[-50:]
    dataseto=pd.DataFrame(dataseto)
    datasetneg=len(dataseto[dataseto['realizedPnl']<0].index)
    datasetpos=len(dataseto[dataseto['realizedPnl']>0].index)
    print(profit,'+',datasetpos,'-',datasetneg)

# %%
def get_direction(symbol):
    trades = client.futures_account_trades(symbol=symbol)[-1:]
    dataset = pd.DataFrame(trades)
    resdata = float(dataset['realizedPnl'])
    direction=1
    if resdata < 0:
        direction=0
    return(direction)

# %%
def changer(symbol):
    direction=get_direction(symbol)
    f = open("directdoc.txt", "r")
    direc=f.read()
    if direction==0: #не меняем
        if direc=='0':
            open_position_long_steps(symbol)
            f = open("directdoc.txt", "w")
            f.write("1")
            f.close()
            print('Direction switched from SHORT to LONG')
        else:
            open_position_short_steps(symbol)
            print('Direction switched from LONG to SHORT')
            f = open("directdoc.txt", "w")
            f.write("0")
            f.close()
    else: #реверс
        if direc=='0':
            target=open_position_short_steps(symbol)
            print('Direction SHORT again')
            f = open("directdoc.txt", "w")
            f.write("0")
            f.close()
        if direc=='1':
            target=open_position_long_steps(symbol)
            print('Direction LONG again')
            f = open("directdoc.txt", "w")
            f.write("1")
            f.close()

# %%
def check_positions_new(symbol):
    positions=get_opened_positions(symbol)
    orders=client.futures_get_open_orders(symbol=symbol)
    orders_df=pd.DataFrame(orders)
    if positions[0]+positions[1]==0:
        if orders_df.empty:
            changer(symbol)
            
    orders_tp=orders_df[orders_df['origType']=='TAKE_PROFIT']
    orders_tp_long=len(orders_tp[orders_tp['positionSide']=='LONG'])
    orders_tp_short=len(orders_tp[orders_tp['positionSide']=='SHORT'])
    if positions[0]>0 and (orders_tp_long==1 or orders_tp_long==3):
        sprice=get_symbol_price(symbol)
        if sprice<(positions[0])*(1+profit_percent/10):
            quant=str(round(get_quant(symbol),roundity))
            params={ 
                "batchOrders": [
                    {
                        "symbol":symbol, 
                        "positionSide": "LONG", 
                        "side":'SELL', 
                        "type":'MARKET',
                        "quantity":quant
                    }
                ]
            }
            one_stop=send_signed_request('POST', '/fapi/v1/batchOrders', params)
            if str(float(one_stop[0]['origQty']))==quant:
                print(f'Compensation LONG price {sprice}')

    if positions[1]>0 and (orders_tp_short==1 or orders_tp_short==3):
        sprice=get_symbol_price(symbol)
        if sprice>(positions[1])*(1-profit_percent/10):
            quant=str(round(get_quant(symbol),roundity))
            params={ 
                "batchOrders": [
                    {
                        "symbol":symbol, 
                        "positionSide": "SHORT", 
                        "side":'BUY', 
                        "type":'MARKET',
                        "quantity":quant
                    }
                ]
            }
            one_stop=send_signed_request('POST', '/fapi/v1/batchOrders', params)
            if str(float(one_stop[0]['origQty']))==quant:
                print(f'Compensation SHORT price {sprice}')
#     else:

#         if positions[0]>0 and positions[1]==0:
#             quant=str(round(get_quant(symbol),roundity))
#             sprice=get_symbol_price(symbol)
#             asset=get_assetbalance(symbol)
#             if (asset*leverage)/(sprice*ingebit*2)>float(quant):
#                 if sprice<positions[0]*(1-profit_percent/4):
#                     sprice=get_symbol_price(symbol)
#                     close_price=str(round(sprice*(1-0.001),symbolround))                
#                     open_position_short(symbol,quant,tick_size,profit_percent/2,stop_percent,close_price)
#                     print('SHORT compensation opened')
#                 else:
#                     print('SHORT compensation not in condition')
#         if positions[1]>0 and positions[0]==0:
#             quant=str(round(get_quant(symbol),roundity))
#             sprice=get_symbol_price(symbol)
#             asset=get_assetbalance(symbol)
#             if (asset*leverage)/(sprice*ingebit*2)>float(quant):
#                 if sprice>positions[1]*(1+profit_percent/4):
#                     sprice=get_symbol_price(symbol)
#                     close_price=str(round(sprice*(1+0.001),symbolround))                
#                     open_position_long(symbol,quant,tick_size,profit_percent/2,stop_percent,close_price)
#                     print('LONG compensation opened')
#                 else:
#                     print('LONG compensation not in condition')

# %%
def check_step(symbol):
    quant=str(get_quant(symbol)*2)
    sprice=get_symbol_price(symbol)
    asset=get_assetbalance(symbol)
    # if (asset*leverage)/(sprice*ingebit*2)>float(quant):
    positions=get_opened_positions(symbol)
    if positions[0]>0:
        if sprice>(positions[0])*(1+profit_percent/2.2):
            sprice=get_symbol_price(symbol)
            close_price=str(round(sprice*(1+0.001),symbolround))
            open_position_long(symbol,quant,tick_size,profit_percent,stop_percent,close_price)
            print('LONG addinational 1')
            # client.futures_cancel_all_open_orders(symbol=symbol)
            # short_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)

    if positions[1]>0:
        if sprice<(positions[1])*(1-profit_percent/2.2):
            sprice=get_symbol_price(symbol)
            close_price=str(round(sprice*(1-0.001),symbolround))
            open_position_short(symbol,quant,tick_size,profit_percent,stop_percent,close_price)
            print('SHORT addinational 1')
            # client.futures_cancel_all_open_orders(symbol=symbol)
            # long_tp_sl_opening(symbol,quantity,profit_percent,stop_percent)

# %%
def order_clean(symbol):
    orders=client.futures_get_open_orders(symbol=symbol)
    orders_df=pd.DataFrame(orders)
    orders_sl=orders_df[orders_df['origType']=='STOP']
    orders_sl_short=pd.DataFrame(orders_sl[orders_sl['positionSide']=='SHORT'])
    orders_sl_long=pd.DataFrame(orders_sl[orders_sl['positionSide']=='LONG'])
    if len(orders_sl_short) > 3:
        ids = orders_sl_short['orderId'][-3:]
        ids_list=ids.values.tolist()
        params = {
            'symbol': symbol,
            'orderIdList': ids_list
        }
        send_signed_request('DELETE', '/fapi/v1/batchOrders', params)
    if len(orders_sl_long) > 3:
        ids = orders_sl_long['orderId'][-3:]
        ids_list=ids.values.tolist()
        params = {
            'symbol': symbol,
            'orderIdList': ids_list
        }
        send_signed_request('DELETE', '/fapi/v1/batchOrders', params)

# %%
def main(step):
    try:
        x = threading.Thread(target=check_positions_new(symbol))
        x.start()
        y = threading.Thread(target=get_profit(symbol))
        y.start()
        z = threading.Thread(target=check_step(symbol))
        z.start()
        w = threading.Thread(target=order_clean(symbol))
        w.start()
    except :
        print('\n\nSomething went wrong. Continuing...')

# %%
def start_stop():
    starttime=time.time()
    counterr=1
    timeout = time.time() + 60*60*6  # 60 seconds times 60 meaning the script will run for 12 hr
    while time.time() <= timeout:
        try:

            print("script continue running at "+time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
            main(counterr)
            counterr=counterr+1
            if counterr>3:
                counterr=1
            time.sleep(4 - ((time.time() - starttime) % 4.0)) # 1 minute interval between each new execution
        except KeyboardInterrupt:
            print('\n\KeyboardInterrupt. Stopping.')

# %%
start_stop()
# Out:
# script continue running at 2022-11-29 16:14:58
# LONG order opened price:1208.35
# Direction switched from SHORT to LONG
#
#
# Something went wrong. Continuing...
# LONG tp order opened price:1208.73
# LONG tp order opened price:1209.82
# LONG sl order opened price:1204.39
# LONG sl order opened price:1203.3
# LONG sl order opened price:1203.84
# script continue running at 2022-11-29 16:15:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:15:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:16:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:17:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:18:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:19:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:20:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:21:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:22:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:22
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:23:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:06
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:10
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:14
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:18
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:26
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:30
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:34
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:38
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:42
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:46
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:50
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:54
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:24:58
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:25:02
# -0.02868762 + 16 - 18
# script continue running at 2022-11-29 16:25:06
# -0.02868762 + 16 - 18
# LONG order opened price:1210.21
# LONG addinational 1
# script continue running at 2022-11-29 16:25:10
# LONG tp order opened price:1209.91
# LONG tp order opened price:1211.0
# LONG sl order opened price:1205.57
# LONG sl order opened price:1204.48
# LONG sl order opened price:1205.02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:26
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:25:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:26
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:26:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:22
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:27:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:26
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:28:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:22
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:29:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:22
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:26
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:30:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:26
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:31:58
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:10
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:14
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:18
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:22
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:26
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:30
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:34
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:38
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:42
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:46
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:50
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:32:54
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:33:02
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:33:06
# -0.03267902 + 16 - 17
# script continue running at 2022-11-29 16:33:10
# -0.02827922 + 16 - 17
# script continue running at 2022-11-29 16:33:14
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:22
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:26
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:30
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:34
# -0.02827922 + 16 - 17
# script continue running at 2022-11-29 16:33:38
# -0.02827922 + 16 - 17
# script continue running at 2022-11-29 16:33:42
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:46
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:50
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:33:54
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:02
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:06
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:10
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:14
# -0.02827922 + 16 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:22
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:26
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:30
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:34
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:38
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:42
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:46
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:50
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:54
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:34:58
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:06
# -0.006488900000000001 + 17 - 17
# script continue running at 2022-11-29 16:35:10
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:14
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:22
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:26
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:30
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:34
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:38
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:42
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:46
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:50
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:54
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:35:58
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:02
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:06
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:10
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:18
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:22
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:26
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:30
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:34
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:38
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:42
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:46
# -0.006488900000000001 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:36:50
# 0.011488169999999999 + 18 - 17
# LONG order opened price:1212.77
# LONG addinational 1
# LONG tp order opened price:1211.92
# LONG tp order opened price:1213.01
# script continue running at 2022-11-29 16:36:54
# LONG sl order opened price:1207.57
# LONG sl order opened price:1206.48
# LONG sl order opened price:1207.02
# 0.0035157400000000033 + 18 - 16
# script continue running at 2022-11-29 16:36:58
# LONG order opened price:1212.83
# Direction LONG again
#
#
# Something went wrong. Continuing...
# LONG tp order opened price:1213.5
# LONG tp order opened price:1214.59
# LONG sl order opened price:1209.14LONG sl order opened price:1208.05
#
# LONG sl order opened price:1208.59
# script continue running at 2022-11-29 16:37:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:06
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:37:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:06
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:38:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:06
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:39:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:06
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:40:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:41:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:42:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:43:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:44:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:06
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:46
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:50
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:54
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:45:58
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:02
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:10
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:14
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:18
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:22
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:26
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:30
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:34
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:38
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:42
# 0.00894135 + 18 - 15
# script continue running at 2022-11-29 16:46:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:46:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:46:54
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:46:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:47:54
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:48:54
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:49:54
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:50:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:51:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:52:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:53:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:54:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:55:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:54
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:56:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:50
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:54
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:57:58
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:02
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:06
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:10
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:14
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:18
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:22
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:26
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:30
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:34
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:38
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:42
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:46
# 0.011454690000000007 + 17 - 17
# script continue running at 2022-11-29 16:58:50
# 0.011454690000000007 + 17 - 17
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:58:54
# SHORT order opened price:1207.61
# Direction switched from LONG to SHORT
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:58:58
# SHORT tp order opened price:1205.25
# SHORT tp order opened price:1206.33
# SHORT sl order opened price:1211.23SHORT sl order opened price:1211.77
#
# SHORT sl order opened price:1210.69
# Compensation SHORT price 1208.81
# 0.0027362799999999937 + 16 - 18
#
#
# Something went wrong. Continuing...
# script continue running at 2022-11-29 16:59:06
# LONG order opened price:1210.24
# Direction switched from SHORT to LONG
#
#
# Something went wrong. Continuing...
# LONG tp order opened price:1211.82
# ...
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:00:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:00:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:00:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:00:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:00:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:01:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:02:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:03:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:04:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:50
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:05:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:50
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:06:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:50
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:07:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:50
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:08:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:50
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:09:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:10
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:14
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:18
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:22
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:26
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:30
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:34
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:38
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:42
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:46
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:50
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:54
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:10:58
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:11:02
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:11:06
# -0.06741230000000001 + 14 - 18
# script continue running at 2022-11-29 22:11:10
# -0.07495216 + 14 - 19
# script continue running at 2022-11-29 22:11:14
# -0.07684041 + 14 - 19
# script continue running at 2022-11-29 22:11:18
# -0.07684041 + 14 - 19
# script continue running at 2022-11-29 22:11:22
# -0.07684041 + 14 - 19
# script continue running at 2022-11-29 22:11:26
# -0.07684041 + 14 - 19
# script continue running at 2022-11-29 22:11:30
# LONG order opened price:1223.81
# Direction switched from SHORT to LONG
#
#
# Something went wrong. Continuing...
# LONG tp order opened price:1224.04
# LONG tp order opened price:1225.14
# LONG sl order opened price:1219.64
# LONG sl order opened price:1218.54
# LONG sl order opened price:1219.09
# script continue running at 2022-11-29 22:11:34
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:11:38
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:11:46
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:11:50
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:11:54
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:11:58
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:12:02
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:12:06
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:12:10
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:12:14
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:12:18
# -0.07774862 + 13 - 20
# script continue running at 2022-11-29 22:12:22
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:26
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:30
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:34
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:38
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:46
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:50
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:54
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:12:58
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:02
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:06
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:10
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:14
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:18
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:22
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:26
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:30
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:34
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:42
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:46
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:50
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:54
# -0.06703229 + 12 - 21
# script continue running at 2022-11-29 22:13:58
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:02
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:06
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:10
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:14
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:18
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:22
# -0.07051083999999999 + 12 - 22
# script continue running at 2022-11-29 22:14:26
# SHORT order opened price:1217.91
# Direction switched from LONG to SHORT
#
#
# Something went wrong. Continuing...
# SHORT tp order opened price:1216.58
# SHORT tp order opened price:1215.48
# SHORT sl order opened price:1220.96SHORT sl order opened price:1221.51
#
# SHORT sl order opened price:1222.06
# script continue running at 2022-11-29 22:14:30
# -0.06419143 + 10 - 23
# script continue running at 2022-11-29 22:14:38
# -0.06419143 + 10 - 23
# script continue running at 2022-11-29 22:14:42
# -0.06419143 + 10 - 23
# script continue running at 2022-11-29 22:14:46
# -0.06419143 + 10 - 23
# script continue running at 2022-11-29 22:14:50
# -0.06419143 + 10 - 23
# script continue running at 2022-11-29 22:14:54
# -0.06419143 + 10 - 23
